# %% [markdown]
# # Important
#
# This notebook is for reproducibility purposes. This is to help with cleaning the data.
#
#
# In the data folder there is a clean example folder. This folder houses the CSVs that I manually cleaned. This notebook will show you the steps of the data cleaning process and justifications.

# %%
# Import Libraries
import os
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# Load Datasets

# ICU Datasets
d_items=pd.read_csv('../data/icu/d_items.csv')
# Provide addition context for resources used
icu_stays=pd.read_csv('../data/icu/icustays.csv')
# ICU Stay data
ingredient_events=pd.read_csv('../data/icu/ingredientevents.csv')
# provides context for ingredients used
input_events=pd.read_csv('../data/icu/inputevents.csv')
# provides input events context
output_events=pd.read_csv('../data/icu/outputevents.csv')
# Provides output events context
procedure_events=pd.read_csv('../data/icu/procedureevents.csv')
# Provides context for procedure events



# Hospital Datasets

admissions=pd.read_csv('../data/hosp/admissions.csv')
# Admission data
hcpcs_code=pd.read_csv('../data/hosp/d_hcpcs.csv')
# Hospital procedure code
diagnoses_code=pd.read_csv('../data/hosp/d_icd_diagnoses.csv')
# Diagnoses codes
d_procedure_code=pd.read_csv('../data/hosp/d_icd_procedures.csv')
# Procedure Codes
labitems=pd.read_csv('../data/hosp/d_labitems.csv')
# Lab item description
diagnoses=pd.read_csv(r"../data/hosp/diagnoses_icd.csv.gz")
# Patient diagnoses data
drgcodes=pd.read_csv('../data/hosp/drgcodes.csv')
# Drug codes
labevents=pd.read_csv('../data/hosp/labevents.csv')
# Lab events
omr=pd.read_csv('../data/hosp/omr.csv')
# OMR
h_output_events=pd.read_csv('../data/hosp/outputevents.csv')
#output events
patients=pd.read_csv('../data/hosp/patients.csv')
# Patient data
prescriptions=pd.read_csv('../data/hosp/prescriptions.csv')
#Prescription
procedure_code=pd.read_csv(r"../data/hosp/procedures_icd.csv.gz")
# Procedure code
services=pd.read_csv('../data/hosp/services.csv')
# Services
transfers=pd.read_csv('../data/hosp/transfers.csv')
# Transfers

# %% [markdown]
# # Data sets not used
#
# Chart_events: Too granular: notates everything that happened regarding a patient.
#
# Date Time events: Doesn't align with the granularity of the project. Too time specific. The time it takes to create and store a chart has little value based on EDA.
#
# Ingredients Event: Dropping doesn't align with the goal
#
# ### Hopsital
#
# EMAR & Emar details : Redundant dataset. Doesn't offer any unique data that I can use. Can get medication from prescription. Not too worried with chart time
# Microbiology events: Note something that we can control with lab procedures. Outside the scope
#
# Pharmacy: Doesn't align with granularity
#
# POE & POE Detail: Not using the order which Physicians entered data. So POE detail is dropped along side POE.
#
# Hospital procedure code: Doesn' join into my data sets. Using other hospital codes

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## ICU Data

# %%
d_items
# Out:
#       itemid                                    label  \
# 0     226228                                   Gender
# 1     226545                                     Race
# 2     229877                      Suction events (CH)
# 3     229875                  Oxygenator visible (CH)
# 4     229266  Cannula sites visually inspected (ECMO)
# ...      ...                                      ...
# 4009  227452                      Tobramycin (Trough)
# 4010  227451                      Tobramycin (Random)
# 4011  227457                           Platelet Count
# 4012  227468                               Fibrinogen
# 4013  227463                                 Cortisol
#
#                                  abbreviation      linksto category unitname  \
# 0                                      Gender  chartevents      ADT      NaN
# 1                                        Race  chartevents      ADT      NaN
# 2                         Suction events (CH)  chartevents     ECMO      NaN
# 3                     Oxygenator visible (CH)  chartevents     ECMO      NaN
# 4     Cannula sites visually inspected (ECMO)  chartevents     ECMO      NaN
# ...                                       ...          ...      ...      ...
# 4009                      Tobramycin (Trough)  chartevents     Labs      NaN
# 4010                      Tobramycin (Random)  chartevents     Labs      NaN
# 4011                           Platelet Count  chartevents     Labs      NaN
# 4012                               Fibrinogen  chartevents     Labs      NaN
# 4013                                 Cortisol  chartevents     Labs      NaN
#
#             param_type  lownormalvalue  highnormalvalue
# 0                 Text             NaN              NaN
# 1                 Text             NaN              NaN
# 2                 Text             NaN              NaN
# 3                 Text             NaN              NaN
# 4                 Text             NaN              NaN
# ...                ...             ...              ...
# 4009  Numeric with tag             NaN              NaN
# 4010  Numeric with tag             NaN              NaN
# 4011  Numeric with tag             NaN              NaN
# 4012  Numeric with tag             NaN              NaN
# 4013  Numeric with tag             NaN              NaN
#
# [4014 rows x 9 columns]

# %%
d_items=d_items.drop(columns=['abbreviation','linksto', 'unitname','param_type','lownormalvalue','highnormalvalue'])

# %%
d_items
# Out:
#       itemid                                    label category
# 0     226228                                   Gender      ADT
# 1     226545                                     Race      ADT
# 2     229877                      Suction events (CH)     ECMO
# 3     229875                  Oxygenator visible (CH)     ECMO
# 4     229266  Cannula sites visually inspected (ECMO)     ECMO
# ...      ...                                      ...      ...
# 4009  227452                      Tobramycin (Trough)     Labs
# 4010  227451                      Tobramycin (Random)     Labs
# 4011  227457                           Platelet Count     Labs
# 4012  227468                               Fibrinogen     Labs
# 4013  227463                                 Cortisol     Labs
#
# [4014 rows x 3 columns]

# %%
icu_stays
# Out:
#      subject_id   hadm_id   stay_id  \
# 0      10018328  23786647  31269608
# 1      10020187  24104168  37509585
# 2      10020187  26842957  32554129
# 3      10012853  27882036  31338022
# 4      10020740  25826145  32145159
# ..          ...       ...       ...
# 135    10020786  23488445  33683112
# 136    10020740  23831430  35026312
# 137    10032725  20611640  30101877
# 138    10037928  24656677  39804682
# 139    10015931  22130791  37093652
#
#                                        first_careunit  \
# 0                                      Neuro Stepdown
# 1     Neuro Surgical Intensive Care Unit (Neuro SICU)
# 2                                  Neuro Intermediate
# 3                                 Trauma SICU (TSICU)
# 4                                 Trauma SICU (TSICU)
# ..                                                ...
# 135  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 136  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 137  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 138  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 139  Medical/Surgical Intensive Care Unit (MICU/SICU)
#
#                                         last_careunit          in_time  \
# 0                                      Neuro Stepdown  4/24/2154 23:03
# 1                                      Neuro Stepdown   1/15/2169 4:56
# 2                                  Neuro Intermediate  2/24/2170 18:18
# 3                                 Trauma SICU (TSICU)  11/26/2176 2:34
# 4                                 Trauma SICU (TSICU)   6/3/2150 20:12
# ..                                                ...              ...
# 135  Medical/Surgical Intensive Care Unit (MICU/SICU)   6/9/2189 12:46
# 136  Medical/Surgical Intensive Care Unit (MICU/SICU)  3/11/2150 15:34
# 137  Medical/Surgical Intensive Care Unit (MICU/SICU)   3/22/2143 6:42
# 138  Medical/Surgical Intensive Care Unit (MICU/SICU)  12/21/2178 6:05
# 139  Medical/Surgical Intensive Care Unit (MICU/SICU)  3/24/2177 21:48
#
#              out_time       los
# 0      5/2/2154 15:55  7.702512
# 1     1/20/2169 15:47  5.452662
# 2     2/25/2170 15:15  0.872685
# 3    11/29/2176 20:58  3.766725
# 4      6/4/2150 21:05  1.037106
# ..                ...       ...
# 135   6/10/2189 22:58  1.424757
# 136    3/19/2150 2:17  7.446424
# 137   3/25/2143 15:05  3.349687
# 138   12/22/2178 2:16  0.840856
# 139   3/29/2177 18:03  4.844086
#
# [140 rows x 8 columns]

# %%
icu_stays=icu_stays.drop(columns=['hadm_id','last_careunit', 'in_time','out_time'])

# In time and out time are dropped due to redunancy. They are used to form LOS (Length of stay)

# %%
icu_stays['subject_id'].nunique()
# Out:
# 100

# %%
icu_stays['first_careunit']= icu_stays['first_careunit'].str.strip().str.lower()

#normalize first_careunit data

# %%
icu_stays.isna().sum()

# There are zero missing in the data set

# First and Last care units are keep to see if is an issue between transporting to care units
# Out:
# subject_id        0
# stay_id           0
# first_careunit    0
# los               0
# dtype: int64

# %%
icu_stays
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 135    10020786  33683112  medical/surgical intensive care unit (micu/sicu)
# 136    10020740  35026312  medical/surgical intensive care unit (micu/sicu)
# 137    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
# 138    10037928  39804682  medical/surgical intensive care unit (micu/sicu)
# 139    10015931  37093652  medical/surgical intensive care unit (micu/sicu)
#
#           los
# 0    7.702512
# 1    5.452662
# 2    0.872685
# 3    3.766725
# 4    1.037106
# ..        ...
# 135  1.424757
# 136  7.446424
# 137  3.349687
# 138  0.840856
# 139  4.844086
#
# [140 rows x 4 columns]

# %%
input_events
# Out:
#        subject_id   hadm_id   stay_id  caregiver_id            starttime  \
# 0        10005817  20626031  32604416          4793  2132-12-16 19:50:00
# 1        10005817  20626031  32604416         92805  2132-12-15 20:15:00
# 2        10005817  20626031  32604416         20310  2132-12-17 09:15:00
# 3        10005817  20626031  32604416         79166  2132-12-16 09:36:00
# 4        10005817  20626031  32604416         92805  2132-12-15 20:10:00
# ...           ...       ...       ...           ...                  ...
# 20399    10019003  29279905  34107647         88156  2153-03-29 20:58:00
# 20400    10019003  29279905  34107647         83144  2153-03-30 00:00:00
# 20401    10019003  29279905  34107647         68979  2153-03-28 02:57:00
# 20402    10019003  29279905  34107647         68979  2153-03-28 06:05:00
# 20403    10019003  29279905  34107647         68979  2153-03-28 04:48:00
#
#                    endtime            storetime  itemid    amount amountuom  \
# 0      2132-12-16 19:51:00  2132-12-16 19:50:00  225798  1.000000      dose
# 1      2132-12-15 20:16:00  2132-12-15 20:11:00  225798  1.000000      dose
# 2      2132-12-17 09:16:00  2132-12-17 09:28:00  225798  1.000000      dose
# 3      2132-12-16 09:37:00  2132-12-16 09:37:00  225798  1.000000      dose
# 4      2132-12-15 21:10:00  2132-12-15 20:10:00  221456  2.000000     grams
# ...                    ...                  ...     ...       ...       ...
# 20399  2153-03-29 20:59:00  2153-03-29 20:58:00  221385  0.500000        mg
# 20400  2153-03-30 00:01:00  2153-03-30 01:24:00  221385  0.500000        mg
# 20401  2153-03-28 04:48:00  2153-03-28 02:58:00  221906  0.319770        mg
# 20402  2153-03-28 08:00:00  2153-03-28 06:11:00  221906  0.110377        mg
# 20403  2153-03-28 06:05:00  2153-03-28 06:11:00  221906  0.147810        mg
#
#        ...                      ordercomponenttypedescription  \
# 0      ...                               Main order parameter
# 1      ...                               Main order parameter
# 2      ...                               Main order parameter
# 3      ...                               Main order parameter
# 4      ...  Additives                                     ...
# ...    ...                                                ...
# 20399  ...                               Main order parameter
# 20400  ...                               Main order parameter
# 20401  ...                               Main order parameter
# 20402  ...                               Main order parameter
# 20403  ...                               Main order parameter
#
#       ordercategorydescription  patientweight  totalamount totalamountuom  \
# 0                    Drug Push           91.0        500.0             ml
# 1                    Drug Push           91.0        500.0             ml
# 2                    Drug Push           91.0        500.0             ml
# 3                    Drug Push           91.0        500.0             ml
# 4                Continuous IV           91.0        100.0             ml
# ...                        ...            ...          ...            ...
# 20399                Drug Push           96.0          NaN            NaN
# 20400                Drug Push           96.0          NaN            NaN
# 20401           Continuous Med           96.0        250.0             ml
# 20402           Continuous Med           96.0        250.0             ml
# 20403           Continuous Med           96.0        250.0             ml
#
#       isopenbag continueinnextdept statusdescription  originalamount  \
# 0             0                  0   FinishedRunning        1.000000
# 1             0                  0   FinishedRunning        1.000000
# 2             0                  0   FinishedRunning        1.000000
# 3             0                  0   FinishedRunning        1.000000
# 4             0                  0   FinishedRunning        2.000000
# ...         ...                ...               ...             ...
# 20399         0                  0   FinishedRunning        0.500000
# 20400         0                  0   FinishedRunning        0.500000
# 20401         0                  0   ChangeDose/Rate        8.000000
# 20402         0                  0            Paused        7.532536
# 20403         0                  0   ChangeDose/Rate        7.680346
#
#        originalrate
# 0          1.000000
# 1          1.000000
# 2          1.000000
# 3          1.000000
# 4          0.033333
# ...             ...
# 20399      0.500000
# 20400      0.500000
# 20401      0.030000
# 20402      0.010000
# 20403      0.020000
#
# [20404 rows x 26 columns]

# %%
input_events.isna().sum()
# Out:
# subject_id                          0
# hadm_id                             0
# stay_id                             0
# caregiver_id                        0
# starttime                           0
# endtime                             0
# storetime                           0
# itemid                              0
# amount                              0
# amountuom                           0
# rate                             9366
# rateuom                          9366
# orderid                             0
# linkorderid                         0
# ordercategoryname                   0
# secondaryordercategoryname       6260
# ordercomponenttypedescription       0
# ordercategorydescription            0
# patientweight                       0
# totalamount                      3314
# totalamountuom                   3312
# isopenbag                           0
# continueinnextdept                  0
# statusdescription                   0
# originalamount                      0
# originalrate                        0
# dtype: int64

# %%
input_events=input_events.drop(columns=['hadm_id','caregiver_id','starttime','endtime','storetime','amount','amountuom','rate',
                                        'rateuom', 'orderid','linkorderid','ordercategoryname','secondaryordercategoryname',
                                        'patientweight','totalamount','totalamountuom','isopenbag','continueinnextdept',
                                        'originalamount','originalrate','statusdescription'])

# %%
input_events
# Out:
#        subject_id   stay_id  itemid  \
# 0        10005817  32604416  225798
# 1        10005817  32604416  225798
# 2        10005817  32604416  225798
# 3        10005817  32604416  225798
# 4        10005817  32604416  221456
# ...           ...       ...     ...
# 20399    10019003  34107647  221385
# 20400    10019003  34107647  221385
# 20401    10019003  34107647  221906
# 20402    10019003  34107647  221906
# 20403    10019003  34107647  221906
#
#                            ordercomponenttypedescription  \
# 0                                   Main order parameter
# 1                                   Main order parameter
# 2                                   Main order parameter
# 3                                   Main order parameter
# 4      Additives                                     ...
# ...                                                  ...
# 20399                               Main order parameter
# 20400                               Main order parameter
# 20401                               Main order parameter
# 20402                               Main order parameter
# 20403                               Main order parameter
#
#       ordercategorydescription
# 0                    Drug Push
# 1                    Drug Push
# 2                    Drug Push
# 3                    Drug Push
# 4                Continuous IV
# ...                        ...
# 20399                Drug Push
# 20400                Drug Push
# 20401           Continuous Med
# 20402           Continuous Med
# 20403           Continuous Med
#
# [20404 rows x 5 columns]

# %%
input_events=input_events.drop_duplicates()

# %%
input_events
# Out:
#        subject_id   stay_id  itemid  \
# 0        10005817  32604416  225798
# 4        10005817  32604416  221456
# 8        10005817  32604416  220949
# 9        10005817  32604416  220949
# 10       10005817  32604416  220949
# ...           ...       ...     ...
# 20389    10019003  34107647  225975
# 20392    10019003  34107647  227522
# 20396    10019003  34107647  227523
# 20399    10019003  34107647  221385
# 20401    10019003  34107647  221906
#
#                            ordercomponenttypedescription  \
# 0                                   Main order parameter
# 4      Additives                                     ...
# 8                                   Main order parameter
# 9                                         Mixed solution
# 10                                        Mixed solution
# ...                                                  ...
# 20389                               Main order parameter
# 20392                               Main order parameter
# 20396                               Main order parameter
# 20399                               Main order parameter
# 20401                               Main order parameter
#
#       ordercategorydescription
# 0                    Drug Push
# 4                Continuous IV
# 8                Continuous IV
# 9               Continuous Med
# 10                   Drug Push
# ...                        ...
# 20389                Drug Push
# 20392            Continuous IV
# 20396            Continuous IV
# 20399                Drug Push
# 20401           Continuous Med
#
# [2851 rows x 5 columns]

# %%
input_events['ordercategorydescription']= input_events['ordercategorydescription'].str.strip().str.lower()
input_events['ordercomponenttypedescription']= input_events['ordercomponenttypedescription'].str.strip().str.lower()

#normalizing variables
# Out:
# C:\Users\tayle\AppData\Local\Temp\ipykernel_3960\1076743687.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input_events['ordercategorydescription']= input_events['ordercategorydescription'].str.strip().str.lower()
# C:\Users\tayle\AppData\Local\Temp\ipykernel_3960\1076743687.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   input_events['ordercomponenttypedescription']= input_events['ordercomponenttypedescription'].str.strip().str.lower()

# %%
#aggregating variables by subject_id

inputs_agg = input_events.groupby('subject_id').agg({
    'ordercomponenttypedescription': lambda x: list(set(x)),
    'ordercategorydescription': lambda x: list(set(x))
}).reset_index()

# %%
inputs_agg
# Out:
#     subject_id                      ordercomponenttypedescription  \
# 0     10000032                             [main order parameter]
# 1     10001217  [additives                                    ...
# 2     10001725  [additives                                    ...
# 3     10002428  [additives                                    ...
# 4     10002495  [additives                                    ...
# ..         ...                                                ...
# 94    10038999  [additives                                    ...
# 95    10039708  [additives                                    ...
# 96    10039831  [additives                                    ...
# 97    10039997  [main order parameter, additives              ...
# 98    10040025  [additives                                    ...
#
#                              ordercategorydescription
# 0                              [continuous iv, bolus]
# 1                   [drug push, continuous iv, bolus]
# 2                   [drug push, continuous iv, bolus]
# 3   [bolus, continuous med, continuous iv, non iv ...
# 4   [bolus, continuous med, continuous iv, non iv ...
# ..                                                ...
# 94  [continuous med, drug push, continuous iv, bolus]
# 95  [continuous med, drug push, continuous iv, bolus]
# 96  [continuous med, drug push, continuous iv, bolus]
# 97  [continuous med, drug push, continuous iv, bolus]
# 98  [continuous med, drug push, continuous iv, bolus]
#
# [99 rows x 3 columns]

# %%
#Reason behind the drops.

#Caregiver is a unique Identifer and doesnt add any value

#Start end and store time dont align with granularity

# Rate and Rateuom had over 45% missing values. I am also more concerned about the dose they received rather than they
# rate the received their prescription

# Orderid and linkedorder are uniqueids

# Secondaryordercategoryname is additon classifier that is redundany. The main category suffices for the ordercategory name

# Original Amount and Original Rate are dropped because tehy aren't of main focus. Mainly want to see trends between whats issued
# and how that affects patients

# %%
output_events
# Out:
#       subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0       10002428  23473524  35479615         29441  2156-05-15 18:00:00
# 1       10002428  23473524  35479615         29441  2156-05-15 12:00:00
# 2       10002428  23473524  35479615         29441  2156-05-15 13:00:00
# 3       10002428  23473524  35479615         29441  2156-05-15 08:00:00
# 4       10002428  23473524  35479615         29441  2156-05-15 14:00:00
# ...          ...       ...       ...           ...                  ...
# 9357    10016742  29281842  37057036         82943  2178-07-07 11:00:00
# 9358    10016742  29281842  37057036         82943  2178-07-07 15:00:00
# 9359    10016742  29281842  37057036         82943  2178-07-07 09:00:00
# 9360    10016742  29281842  37057036         82943  2178-07-07 18:00:00
# 9361    10016742  29281842  37057036         82943  2178-07-07 17:00:00
#
#                 storetime  itemid  value valueuom
# 0     2156-05-15 17:42:00  226583    600       ml
# 1     2156-05-15 12:08:00  226559     60       ml
# 2     2156-05-15 13:00:00  226559     45       ml
# 3     2156-05-15 08:39:00  226559    125       ml
# 4     2156-05-15 13:56:00  226559     60       ml
# ...                   ...     ...    ...      ...
# 9357  2178-07-07 13:25:00  226559    230       ml
# 9358  2178-07-07 17:40:00  226559    120       ml
# 9359  2178-07-07 09:25:00  226559    250       ml
# 9360  2178-07-07 18:18:00  226559     80       ml
# 9361  2178-07-07 18:18:00  226559    160       ml
#
# [9362 rows x 9 columns]

# %%
output_events.isna().sum()
# Out:
# subject_id      0
# hadm_id         0
# stay_id         0
# caregiver_id    0
# charttime       0
# storetime       0
# itemid          0
# value           0
# valueuom        0
# dtype: int64

# %%
output_events=output_events.drop(columns=['hadm_id','caregiver_id', 'charttime','storetime'])

# Caregiver is being removed because its a uniqueid
# Not using the times. They don't align with my granularity

# %%
output_events
# Out:
#       subject_id   stay_id  itemid  value valueuom
# 0       10002428  35479615  226583    600       ml
# 1       10002428  35479615  226559     60       ml
# 2       10002428  35479615  226559     45       ml
# 3       10002428  35479615  226559    125       ml
# 4       10002428  35479615  226559     60       ml
# ...          ...       ...     ...    ...      ...
# 9357    10016742  37057036  226559    230       ml
# 9358    10016742  37057036  226559    120       ml
# 9359    10016742  37057036  226559    250       ml
# 9360    10016742  37057036  226559     80       ml
# 9361    10016742  37057036  226559    160       ml
#
# [9362 rows x 5 columns]

# %%
procedure_events.isna().sum()
# Out:
# subject_id                     0
# hadm_id                        0
# stay_id                        0
# caregiver_id                 242
# starttime                      0
# endtime                        0
# storetime                      0
# itemid                         0
# value                          0
# valueuom                     771
# location                    1115
# locationcategory            1115
# orderid                        0
# linkorderid                    0
# ordercategoryname              0
# ordercategorydescription       0
# patientweight                  0
# isopenbag                      0
# continueinnextdept             0
# statusdescription              0
# ORIGINALAMOUNT                 0
# ORIGINALRATE                   0
# dtype: int64

# %%
procedure_events['location'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1468 entries, 0 to 1467
# Series name: location
# Non-Null Count  Dtype
# --------------  -----
# 353 non-null    object
# dtypes: object(1)
# memory usage: 11.6+ KB

# %%
procedure_events=procedure_events.drop(columns=['hadm_id','caregiver_id', 'starttime','endtime',
                                                'storetime','value','valueuom','location','locationcategory','orderid','linkorderid',
                                               'patientweight','isopenbag','continueinnextdept','statusdescription','ORIGINALAMOUNT',
                                               'ORIGINALRATE'])

# %%
procedure_events['ordercategoryname']= procedure_events['ordercategoryname'].str.strip().str.lower()
procedure_events['ordercategorydescription']= procedure_events['ordercategorydescription'].str.strip().str.lower()


#normalizing variables

# %%
proc_agg = procedure_events.groupby('subject_id').agg({
    'ordercategoryname': lambda x: list(set(x)),
    'ordercategorydescription': lambda x: list(set(x))
}).reset_index()

# %%
proc_agg
# Out:
#     subject_id                                  ordercategoryname  \
# 0     10000032                     [peripheral lines, procedures]
# 1     10001217  [imaging, invasive lines, peripheral lines, co...
# 2     10001725                                 [peripheral lines]
# 3     10002428  [communication, ventilation, imaging, intubati...
# 4     10002495  [communication, ventilation, imaging, tubes, p...
# ..         ...                                                ...
# 95    10038999  [communication, ventilation, imaging, tubes, i...
# 96    10039708  [ventilation, imaging, tubes, intubation/extub...
# 97    10039831  [imaging, invasive lines, peripheral lines, pr...
# 98    10039997        [imaging, invasive lines, peripheral lines]
# 99    10040025  [ventilation, imaging, tubes, intubation/extub...
#
#      ordercategorydescription
# 0   [task, continuousprocess]
# 1   [task, continuousprocess]
# 2         [continuousprocess]
# 3   [task, continuousprocess]
# 4   [task, continuousprocess]
# ..                        ...
# 95  [task, continuousprocess]
# 96  [task, continuousprocess]
# 97  [task, continuousprocess]
# 98  [task, continuousprocess]
# 99  [task, continuousprocess]
#
# [100 rows x 3 columns]

# %%
#Dropping caregiver id because its a uniqueid
# Dropping times as they doing align with my granularity
# dropping location and location category as over 75% of the data is missing.

# %% [markdown]
# ## Hospital

# %%
admissions
# Out:
#      subject_id   hadm_id            admittime            dischtime  \
# 0      10004235  24181354  2196-02-24 14:38:00  2196-03-04 14:02:00
# 1      10009628  25926192  2153-09-17 17:08:00  2153-09-25 13:20:00
# 2      10018081  23983182  2134-08-18 02:02:00  2134-08-23 19:35:00
# 3      10006053  22942076  2111-11-13 23:39:00  2111-11-15 17:20:00
# 4      10031404  21606243  2113-08-04 18:46:00  2113-08-06 20:57:00
# ..          ...       ...                  ...                  ...
# 270    10038992  24745425  2187-07-29 01:05:00  2187-08-03 17:02:00
# 271    10008287  22168393  2145-09-28 01:17:00  2145-10-02 13:35:00
# 272    10022880  27708593  2177-03-12 07:15:00  2177-03-19 14:25:00
# 273    10004457  23251352  2141-12-17 11:00:00  2141-12-21 15:56:00
# 274    10004457  28108313  2147-12-19 00:00:00  2147-12-21 16:10:00
#
#                deathtime               admission_type admit_provider_id  \
# 0                    NaN                       URGENT            P03YMR
# 1                    NaN                       URGENT            P41R5N
# 2                    NaN                       URGENT            P233F6
# 3    2111-11-15 17:20:00                       URGENT            P38TI6
# 4                    NaN                       URGENT            P07HDB
# ..                   ...                          ...               ...
# 270                  NaN  SURGICAL SAME DAY ADMISSION            P41R5N
# 271                  NaN  SURGICAL SAME DAY ADMISSION            P898NM
# 272                  NaN  SURGICAL SAME DAY ADMISSION            P99698
# 273                  NaN  SURGICAL SAME DAY ADMISSION            P41R5N
# 274                  NaN  SURGICAL SAME DAY ADMISSION            P10WWR
#
#          admission_location        discharge_location insurance language  \
# 0    TRANSFER FROM HOSPITAL  SKILLED NURSING FACILITY  Medicaid  ENGLISH
# 1    TRANSFER FROM HOSPITAL          HOME HEALTH CARE  Medicaid        ?
# 2    TRANSFER FROM HOSPITAL  SKILLED NURSING FACILITY  Medicare  ENGLISH
# 3    TRANSFER FROM HOSPITAL                      DIED  Medicaid  ENGLISH
# 4    TRANSFER FROM HOSPITAL                      HOME     Other  ENGLISH
# ..                      ...                       ...       ...      ...
# 270      PHYSICIAN REFERRAL  SKILLED NURSING FACILITY  Medicare  ENGLISH
# 271      PHYSICIAN REFERRAL          HOME HEALTH CARE     Other  ENGLISH
# 272      PHYSICIAN REFERRAL                      HOME  Medicare  ENGLISH
# 273      PHYSICIAN REFERRAL                     REHAB  Medicare  ENGLISH
# 274      PHYSICIAN REFERRAL  SKILLED NURSING FACILITY  Medicare  ENGLISH
#
#     marital_status                            race            edregtime  \
# 0           SINGLE              BLACK/CAPE VERDEAN  2196-02-24 12:15:00
# 1          MARRIED  HISPANIC/LATINO - PUERTO RICAN                  NaN
# 2          MARRIED                           WHITE  2134-08-17 16:24:00
# 3              NaN                         UNKNOWN                  NaN
# 4          WIDOWED                           WHITE                  NaN
# ..             ...                             ...                  ...
# 270        MARRIED                           WHITE                  NaN
# 271         SINGLE                           WHITE                  NaN
# 272        MARRIED                           WHITE                  NaN
# 273         SINGLE                           OTHER                  NaN
# 274       DIVORCED                           WHITE                  NaN
#
#                edouttime  hospital_expire_flag
# 0    2196-02-24 17:07:00                     0
# 1                    NaN                     0
# 2    2134-08-18 03:15:00                     0
# 3                    NaN                     1
# 4                    NaN                     0
# ..                   ...                   ...
# 270                  NaN                     0
# 271                  NaN                     0
# 272                  NaN                     0
# 273                  NaN                     0
# 274                  NaN                     0
#
# [275 rows x 16 columns]

# %%
admissions=admissions.drop(columns=['hadm_id','admittime','dischtime','deathtime','admission_type','admit_provider_id','admission_location',
                                   'discharge_location','edregtime','edouttime','hospital_expire_flag'])

# %%
admissions.isna().sum()
# Out:
# subject_id         0
# insurance          0
# language           0
# marital_status    12
# race               0
# dtype: int64

# %%
admissions['insurance']= admissions['insurance'].str.strip().str.lower()
admissions['language']= admissions['language'].str.strip().str.lower()
admissions['marital_status']= admissions['marital_status'].str.strip().str.lower()
admissions['race']= admissions['race'].str.strip().str.lower()

#normalizing variables

# %%
adm_agg=admissions.groupby('subject_id').agg({
    'insurance': lambda x: list(set(x)),
    'language': lambda x: list(set(x)),
    'marital_status': lambda x: list(set(x)),
    'race': lambda x: list(set(x))
}).reset_index()

# %%
adm_agg
# Out:
#     subject_id          insurance   language      marital_status  \
# 0     10000032  [other, medicaid]  [english]           [widowed]
# 1     10001217            [other]        [?]           [married]
# 2     10001725            [other]  [english]           [married]
# 3     10002428         [medicare]  [english]           [widowed]
# 4     10002495         [medicare]  [english]           [married]
# ..         ...                ...        ...                 ...
# 95    10038999         [medicare]  [english]            [single]
# 96    10039708            [other]  [english]            [single]
# 97    10039831            [other]  [english]           [married]
# 98    10039997         [medicare]  [english]  [married, widowed]
# 99    10040025            [other]  [english]          [divorced]
#
#                         race
# 0                    [white]
# 1                    [white]
# 2                    [white]
# 3                    [white]
# 4                  [unknown]
# ..                       ...
# 95                   [white]
# 96  [black/african american]
# 97        [unable to obtain]
# 98  [black/african american]
# 99                   [white]
#
# [100 rows x 5 columns]

# %%
# Admittime, dischtime, edregtime, edouttime. Don't align with my scope removing time
# admission location is out of our control so its being removed
# Discharge location: Patients should be healthy enough to where they don't die if they are being discharged
# Admit Provider ID provides no information. Its a unique id

# %%
diagnoses_code
# Out:
#        icd_code  icd_version  \
# 0          0090            9
# 1         01160            9
# 2         01186            9
# 3         01200            9
# 4         01236            9
# ...         ...          ...
# 109770      Z88           10
# 109771   Z89012           10
# 109772   Z90410           10
# 109773     Z948           10
# 109774      Z96           10
#
#                                                long_title
# 0       Infectious colitis, enteritis, and gastroenter...
# 1           Tuberculous pneumonia [any form], unspecified
# 2       Other specified pulmonary tuberculosis, tuberc...
# 3                       Tuberculous pleurisy, unspecified
# 4       Tuberculous laryngitis, tubercle bacilli not f...
# ...                                                   ...
# 109770  Allergy status to drugs, medicaments and biolo...
# 109771                     Acquired absence of left thumb
# 109772                 Acquired total absence of pancreas
# 109773         Other transplanted organ and tissue status
# 109774              Presence of other functional implants
#
# [109775 rows x 3 columns]

# %%
diagnoses_code['long_title']= diagnoses_code['long_title'].str.strip().str.lower()

# %%
diagnoses_code.isna().sum()

#its worth considering dropping all the data that uses version 9 as its outdate
# Out:
# icd_code       0
# icd_version    0
# long_title     0
# dtype: int64

# %%
d_procedure_code
# Out:
#       icd_code  icd_version                                         long_title
# 0         0039            9                    Other computer assisted surgery
# 1         0048            9          Insertion of four or more vascular stents
# 2         0074            9         Hip bearing surface, metal-on-polyethylene
# 3         0077            9       Hip bearing surface, ceramic-on-polyethylene
# 4         0126            9  Insertion of catheter(s) into cranial cavity o...
# ...        ...          ...                                                ...
# 85252  F15Z68Z           10  Computerized Dynamic Posturography Assessment ...
# 85253  HZ37ZZZ           10  Individual Counseling for Substance Abuse Trea...
# 85254  X27L395           10  Dilation of Proximal Left Popliteal Artery wit...
# 85255  X2C0361           10  Extirpation of Matter from Coronary Artery, On...
# 85256      XRG           10                     New Technology, Joints, Fusion
#
# [85257 rows x 3 columns]

# %%
d_procedure_code['long_title']= d_procedure_code['long_title'].str.strip().str.lower()

# %%
d_procedure_code.isna().sum()
# Out:
# icd_code       0
# icd_version    0
# long_title     0
# dtype: int64

# %%
labitems
# Out:
#       itemid                       label                fluid    category
# 0      50808                Free Calcium                Blood   Blood Gas
# 1      50826                Tidal Volume                Blood   Blood Gas
# 2      50813                     Lactate                Blood   Blood Gas
# 3      52029           % Ionized Calcium                Blood   Blood Gas
# 4      50801  Alveolar-arterial Gradient                Blood   Blood Gas
# ...      ...                         ...                  ...         ...
# 1617   52249                      Delete  Cerebrospinal Fluid  Hematology
# 1618   52251                      Delete  Cerebrospinal Fluid  Hematology
# 1619   52266                  Macrophage  Cerebrospinal Fluid  Hematology
# 1620   52262           Immunophenotyping  Cerebrospinal Fluid  Hematology
# 1621   52265                     Lymphs#  Cerebrospinal Fluid  Hematology
#
# [1622 rows x 4 columns]

# %%
labitems.isna().sum()
# Out:
# itemid      0
# label       3
# fluid       0
# category    0
# dtype: int64

# %%
# 3 missings is minimal. Will keep the data description as is

# %%
diagnoses
# Out:
#       subject_id   hadm_id  seq_num icd_code  icd_version
# 0       10035185  22580999        3     4139            9
# 1       10035185  22580999       10     V707            9
# 2       10035185  22580999        1    41401            9
# 3       10035185  22580999        9     3899            9
# 4       10035185  22580999       11    V8532            9
# ...          ...       ...      ...      ...          ...
# 4501    10004733  27411876       19     3129            9
# 4502    10004733  27411876       30    30000            9
# 4503    10004733  27411876       26     4739            9
# 4504    10004733  27411876       22    56210            9
# 4505    10004733  27411876       29    30390            9
#
# [4506 rows x 5 columns]

# %%
diagnoses=diagnoses.drop(columns=['hadm_id','seq_num'])

# %%
# Not too concern with the order of the diagnoses so I am dropping seq_number.

# %%
drgcodes
# Out:
#      subject_id   hadm_id drg_type  drg_code  \
# 0      10004235  22187210     HCFA       864
# 1      10026255  22059910     HCFA       180
# 2      10032725  20611640     HCFA        54
# 3      10005866  21636229     HCFA       393
# 4      10008454  20291550     HCFA       956
# ..          ...       ...      ...       ...
# 449    10040025  27259207     HCFA       982
# 450    10001725  25563031     HCFA       982
# 451    10023239  21759936     HCFA       987
# 452    10019003  26529390     HCFA       987
# 453    10003400  23559586     HCFA       987
#
#                                            description  drg_severity  \
# 0                                                FEVER           NaN
# 1                          RESPIRATORY NEOPLASMS W MCC           NaN
# 2                       NERVOUS SYSTEM NEOPLASMS W MCC           NaN
# 3               OTHER DIGESTIVE SYSTEM DIAGNOSES W MCC           NaN
# 4    LIMB REATTACHMENT, HIP & FEMUR PROC FOR MULTIP...           NaN
# ..                                                 ...           ...
# 449  EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPA...           NaN
# 450  EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPA...           NaN
# 451  NON-EXTENSIVE O.R. PROC UNRELATED TO PRINCIPAL...           NaN
# 452  NON-EXTENSIVE O.R. PROC UNRELATED TO PRINCIPAL...           NaN
# 453  NON-EXTENSIVE O.R. PROC UNRELATED TO PRINCIPAL...           NaN
#
#      drg_mortality
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ..             ...
# 449            NaN
# 450            NaN
# 451            NaN
# 452            NaN
# 453            NaN
#
# [454 rows x 7 columns]

# %%
drgcodes['drg_severity'] = drgcodes['drg_severity'].astype('object')
drgcodes['drg_mortality'] = drgcodes['drg_mortality'].astype('object')

# %%
severity_map={1:'mild',
              2:'moderate',
              3:'severe',
             4:'critical'}

drgcodes.loc[drgcodes['drg_severity'].notna(),'drg_severity']=drgcodes['drg_severity'].map(severity_map)

# %%
mortality_risk_map={
              1:'minor',
              2:'moderate',
              3:'major',
             4:'extreme'}

drgcodes.loc[drgcodes['drg_mortality'].notna(),'drg_mortality']=drgcodes['drg_mortality'].map(mortality_risk_map)

# %%
drgcodes
# Out:
#      subject_id   hadm_id drg_type  drg_code  \
# 0      10004235  22187210     HCFA       864
# 1      10026255  22059910     HCFA       180
# 2      10032725  20611640     HCFA        54
# 3      10005866  21636229     HCFA       393
# 4      10008454  20291550     HCFA       956
# ..          ...       ...      ...       ...
# 449    10040025  27259207     HCFA       982
# 450    10001725  25563031     HCFA       982
# 451    10023239  21759936     HCFA       987
# 452    10019003  26529390     HCFA       987
# 453    10003400  23559586     HCFA       987
#
#                                            description drg_severity  \
# 0                                                FEVER          NaN
# 1                          RESPIRATORY NEOPLASMS W MCC          NaN
# 2                       NERVOUS SYSTEM NEOPLASMS W MCC          NaN
# 3               OTHER DIGESTIVE SYSTEM DIAGNOSES W MCC          NaN
# 4    LIMB REATTACHMENT, HIP & FEMUR PROC FOR MULTIP...          NaN
# ..                                                 ...          ...
# 449  EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPA...          NaN
# 450  EXTENSIVE O.R. PROCEDURE UNRELATED TO PRINCIPA...          NaN
# 451  NON-EXTENSIVE O.R. PROC UNRELATED TO PRINCIPAL...          NaN
# 452  NON-EXTENSIVE O.R. PROC UNRELATED TO PRINCIPAL...          NaN
# 453  NON-EXTENSIVE O.R. PROC UNRELATED TO PRINCIPAL...          NaN
#
#     drg_mortality
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ..            ...
# 449           NaN
# 450           NaN
# 451           NaN
# 452           NaN
# 453           NaN
#
# [454 rows x 7 columns]

# %%
drgcodes=drgcodes.drop(columns=['hadm_id'])

# %%
drgcodes.isna().sum()
# Out:
# subject_id         0
# drg_type           0
# drg_code           0
# description        0
# drg_severity     233
# drg_mortality    233
# dtype: int64

# %%
drgcodes['drg_mortality'].unique()
# Out:
# array([nan, 'minor', 'moderate', 'major', 'extreme'], dtype=object)

# %%
# Diagnosis-related group. drg severity and moratlity changed to object. INstead of 1-4 its minor, to extreme etc. Easier to understand

# %%
labevents
# Out:
#         labevent_id  subject_id     hadm_id  specimen_id  itemid  \
# 0            172061    10014354  29600294.0      1808066   51277
# 1            172062    10014354  29600294.0      1808066   51279
# 2            172068    10014354  29600294.0      1808066   52172
# 3            172063    10014354  29600294.0      1808066   51301
# 4            172050    10014354  29600294.0      1808066   51249
# ...             ...         ...         ...          ...     ...
# 107722       254700    10021487  28998349.0     78791160   50804
# 107723       254702    10021487  28998349.0     78791160   50818
# 107724       254707    10021487  28998349.0     78791160   52033
# 107725       254706    10021487  28998349.0     78791160   50825
# 107726       454886    10038999  27189241.0     13534028   50873
#
#        order_provider_id            charttime            storetime value  \
# 0                    NaN  2148-08-16 00:00:00  2148-08-16 01:30:00  15.4
# 1                    NaN  2148-08-16 00:00:00  2148-08-16 01:30:00  3.35
# 2                    NaN  2148-08-16 00:00:00  2148-08-16 01:30:00  49.7
# 3                    NaN  2148-08-16 00:00:00  2148-08-16 01:30:00  20.3
# 4                    NaN  2148-08-16 00:00:00  2148-08-16 01:30:00  31.1
# ...                  ...                  ...                  ...   ...
# 107722               NaN  2116-12-07 18:59:00  2116-12-07 19:00:00    35
# 107723               NaN  2116-12-07 18:59:00  2116-12-07 19:00:00    56
# 107724               NaN  2116-12-07 18:59:00  2116-12-07 18:59:00  ART.
# 107725               NaN  2116-12-07 18:59:00  2116-12-07 18:59:00  39.7
# 107726               NaN  2131-05-23 21:59:00  2131-05-25 14:36:00   ___
#
#         valuenum valueuom  ref_range_lower  ref_range_upper      flag  \
# 0          15.40        %             10.5             15.5       NaN
# 1           3.35     m/uL              4.6              6.1  abnormal
# 2          49.70       fL             35.1             46.3  abnormal
# 3          20.30     K/uL              4.0             10.0  abnormal
# 4          31.10     g/dL             32.0             37.0  abnormal
# ...          ...      ...              ...              ...       ...
# 107722     35.00    mEq/L             21.0             30.0  abnormal
# 107723     56.00    mm Hg             35.0             45.0  abnormal
# 107724       NaN      NaN              NaN              NaN       NaN
# 107725     39.70      NaN              NaN              NaN       NaN
# 107726       NaN      NaN              NaN              NaN       NaN
#
#        priority   comments
# 0       ROUTINE        NaN
# 1       ROUTINE        NaN
# 2       ROUTINE        NaN
# 3       ROUTINE        NaN
# 4       ROUTINE        NaN
# ...         ...        ...
# 107722      NaN        NaN
# 107723      NaN        NaN
# 107724      NaN        ___
# 107725      NaN        NaN
# 107726     STAT  NEGATIVE.
#
# [107727 rows x 16 columns]

# %%
labevents.isna().sum()
# Out:
# labevent_id              0
# subject_id               0
# hadm_id              28420
# specimen_id              0
# itemid                   0
# order_provider_id    90897
# charttime                0
# storetime              992
# value                 9588
# valuenum             12481
# valueuom             16203
# ref_range_lower      18728
# ref_range_upper      18728
# flag                 67452
# priority              9329
# comments             89273
# dtype: int64

# %%
labevents=labevents.drop(columns=['hadm_id','order_provider_id','charttime','storetime','valuenum','comments'])

# %%
labevents
# Out:
#         labevent_id  subject_id  specimen_id  itemid value valueuom  \
# 0            172061    10014354      1808066   51277  15.4        %
# 1            172062    10014354      1808066   51279  3.35     m/uL
# 2            172068    10014354      1808066   52172  49.7       fL
# 3            172063    10014354      1808066   51301  20.3     K/uL
# 4            172050    10014354      1808066   51249  31.1     g/dL
# ...             ...         ...          ...     ...   ...      ...
# 107722       254700    10021487     78791160   50804    35    mEq/L
# 107723       254702    10021487     78791160   50818    56    mm Hg
# 107724       254707    10021487     78791160   52033  ART.      NaN
# 107725       254706    10021487     78791160   50825  39.7      NaN
# 107726       454886    10038999     13534028   50873   ___      NaN
#
#         ref_range_lower  ref_range_upper      flag priority
# 0                  10.5             15.5       NaN  ROUTINE
# 1                   4.6              6.1  abnormal  ROUTINE
# 2                  35.1             46.3  abnormal  ROUTINE
# 3                   4.0             10.0  abnormal  ROUTINE
# 4                  32.0             37.0  abnormal  ROUTINE
# ...                 ...              ...       ...      ...
# 107722             21.0             30.0  abnormal      NaN
# 107723             35.0             45.0  abnormal      NaN
# 107724              NaN              NaN       NaN      NaN
# 107725              NaN              NaN       NaN      NaN
# 107726              NaN              NaN       NaN     STAT
#
# [107727 rows x 10 columns]

# %%
# Comments didn't provide valuable insights
#valuenum and value are pretty much the same column. Only difference is how values missing are listed. 
# Time isn't my concerned so removed
# Not too worried who ordered

# Ref_ranges blanks means that there is not a range. 
# Flags being blank is essentially abnormal or normal

# %%
omr
# Out:
#       subject_id   chartdate  seq_num      result_name result_value
# 0       10011398  2146-12-01        1  Height (Inches)           63
# 1       10011398  2147-01-22        1     Weight (Lbs)          127
# 2       10011398  2146-12-01        1     Weight (Lbs)          135
# 3       10011398  2147-07-24        1     Weight (Lbs)          136
# 4       10011398  2147-03-26        1     Weight (Lbs)          136
# ...          ...         ...      ...              ...          ...
# 2959    10021118  2161-11-15        1  Height (Inches)           71
# 2960    10021118  2161-11-15        1      BMI (kg/m2)         35.2
# 2961    10021118  2161-11-29        1   Blood Pressure       111/72
# 2962    10021118  2161-12-25        1   Blood Pressure       135/76
# 2963    10021118  2161-11-15        1     Weight (Lbs)       252.65
#
# [2964 rows x 5 columns]

# %%
omr['chartdate']=pd.to_datetime(omr['chartdate'])
omr=omr.sort_values(['subject_id','chartdate'])

# %%
# Ivisit_Id Independent visit id. Only used for OMR
omr['ivisit_id']=omr.groupby('subject_id')['chartdate'].rank(method='dense').astype(int)

# %%
omr
# Out:
#       subject_id  chartdate  seq_num      result_name result_value  ivisit_id
# 1204    10000032 2180-04-27        1     Weight (Lbs)           94          1
# 1241    10000032 2180-04-27        1   Blood Pressure       110/65          1
# 1203    10000032 2180-05-07        1  Height (Inches)           60          2
# 1207    10000032 2180-05-07        1      BMI (kg/m2)         18.0          2
# 1218    10000032 2180-05-07       17     Weight (Lbs)        92.15          2
# ...          ...        ...      ...              ...          ...        ...
# 2689    10040025 2147-12-29        1     Weight (Lbs)          212          9
# 2696    10040025 2147-12-29        1      BMI (kg/m2)         34.2          9
# 2692    10040025 2147-12-30        1      BMI (kg/m2)         30.3         10
# 2704    10040025 2147-12-30        1     Weight (Lbs)       187.61         10
# 2703    10040025 2148-01-19        1   Blood Pressure       112/60         11
#
# [2964 rows x 6 columns]

# %%
omr=omr.drop(columns=['chartdate','seq_num'])

# %%
omr=omr.pivot_table(
index=['subject_id','ivisit_id'],
columns='result_name',
values='result_value',
aggfunc='last').reset_index()

# %%
omr
# Out:
# result_name  subject_id  ivisit_id BMI (kg/m2) Blood Pressure  \
# 0              10000032          1         NaN         110/65
# 1              10000032          2        18.0            NaN
# 2              10000032          3        18.6         106/60
# 3              10000032          4        18.7         121/77
# 4              10000032          5        18.9         100/60
# ..                  ...        ...         ...            ...
# 951            10040025          7        30.3            NaN
# 952            10040025          8        32.3            NaN
# 953            10040025          9        34.2            NaN
# 954            10040025         10        30.3            NaN
# 955            10040025         11         NaN         112/60
#
# result_name Blood Pressure Lying Blood Pressure Sitting  \
# 0                            NaN                    NaN
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                    NaN
# ..                           ...                    ...
# 951                          NaN                    NaN
# 952                          NaN                    NaN
# 953                          NaN                    NaN
# 954                          NaN                    NaN
# 955                          NaN                    NaN
#
# result_name Blood Pressure Standing (1 min) Blood Pressure Standing (3 mins)  \
# 0                                       NaN                              NaN
# 1                                       NaN                              NaN
# 2                                       NaN                              NaN
# 3                                       NaN                              NaN
# 4                                       NaN                              NaN
# ..                                      ...                              ...
# 951                                     NaN                              NaN
# 952                                     NaN                              NaN
# 953                                     NaN                              NaN
# 954                                     NaN                              NaN
# 955                                     NaN                              NaN
#
# result_name Height (Inches) Weight (Lbs)
# 0                       NaN           94
# 1                        60        92.15
# 2                       NaN           95
# 3                       NaN         95.7
# 4                        60           97
# ..                      ...          ...
# 951                     NaN       188.00
# 952                     NaN       200.00
# 953                     NaN          212
# 954                     NaN       187.61
# 955                     NaN          NaN
#
# [956 rows x 10 columns]

# %%
omr.isna().sum()
# Out:
# result_name
# subject_id                            0
# ivisit_id                             0
# BMI (kg/m2)                         195
# Blood Pressure                      129
# Blood Pressure Lying                954
# Blood Pressure Sitting              954
# Blood Pressure Standing (1 min)     955
# Blood Pressure Standing (3 mins)    955
# Height (Inches)                     581
# Weight (Lbs)                        151
# dtype: int64

# %%
omr=omr.drop(columns=["Blood Pressure Lying",'Blood Pressure Sitting',"Blood Pressure Standing (1 min)", "Blood Pressure Standing (3 mins)"])

# %%
omr
# Out:
# result_name  subject_id  ivisit_id BMI (kg/m2) Blood Pressure Height (Inches)  \
# 0              10000032          1         NaN         110/65             NaN
# 1              10000032          2        18.0            NaN              60
# 2              10000032          3        18.6         106/60             NaN
# 3              10000032          4        18.7         121/77             NaN
# 4              10000032          5        18.9         100/60              60
# ..                  ...        ...         ...            ...             ...
# 951            10040025          7        30.3            NaN             NaN
# 952            10040025          8        32.3            NaN             NaN
# 953            10040025          9        34.2            NaN             NaN
# 954            10040025         10        30.3            NaN             NaN
# 955            10040025         11         NaN         112/60             NaN
#
# result_name Weight (Lbs)
# 0                     94
# 1                  92.15
# 2                     95
# 3                   95.7
# 4                     97
# ..                   ...
# 951               188.00
# 952               200.00
# 953                  212
# 954               187.61
# 955                  NaN
#
# [956 rows x 6 columns]

# %%
omr.isna().sum()
# Out:
# result_name
# subject_id           0
# ivisit_id            0
# BMI (kg/m2)        195
# Blood Pressure     129
# Height (Inches)    581
# Weight (Lbs)       151
# dtype: int64

# %%
# Back filling height. Weight the age range of the patients being 21+ its highly unlikely that the patients height has changed
# so height data is back filled
omr['Height (Inches)'] = omr.groupby('subject_id')['Height (Inches)'].ffill()

# %%
omr.isna().sum()
# Out:
# result_name
# subject_id           0
# ivisit_id            0
# BMI (kg/m2)        195
# Blood Pressure     129
# Height (Inches)    121
# Weight (Lbs)       151
# dtype: int64

# %%
# Less than 20% data missing for BMI so I data would be kept

# %%
h_output_events
# Out:
#       subject_id   hadm_id   stay_id  caregiver_id            charttime  \
# 0       10002428  23473524  35479615         29441  2156-05-15 18:00:00
# 1       10002428  23473524  35479615         29441  2156-05-15 12:00:00
# 2       10002428  23473524  35479615         29441  2156-05-15 13:00:00
# 3       10002428  23473524  35479615         29441  2156-05-15 08:00:00
# 4       10002428  23473524  35479615         29441  2156-05-15 14:00:00
# ...          ...       ...       ...           ...                  ...
# 9357    10016742  29281842  37057036         82943  2178-07-07 11:00:00
# 9358    10016742  29281842  37057036         82943  2178-07-07 15:00:00
# 9359    10016742  29281842  37057036         82943  2178-07-07 09:00:00
# 9360    10016742  29281842  37057036         82943  2178-07-07 18:00:00
# 9361    10016742  29281842  37057036         82943  2178-07-07 17:00:00
#
#                 storetime  itemid  value valueuom
# 0     2156-05-15 17:42:00  226583    600       ml
# 1     2156-05-15 12:08:00  226559     60       ml
# 2     2156-05-15 13:00:00  226559     45       ml
# 3     2156-05-15 08:39:00  226559    125       ml
# 4     2156-05-15 13:56:00  226559     60       ml
# ...                   ...     ...    ...      ...
# 9357  2178-07-07 13:25:00  226559    230       ml
# 9358  2178-07-07 17:40:00  226559    120       ml
# 9359  2178-07-07 09:25:00  226559    250       ml
# 9360  2178-07-07 18:18:00  226559     80       ml
# 9361  2178-07-07 18:18:00  226559    160       ml
#
# [9362 rows x 9 columns]

# %%
h_output_events=h_output_events.drop(columns=['caregiver_id','charttime','storetime'])

# %%
h_output_events
# Out:
#       subject_id   hadm_id   stay_id  itemid  value valueuom
# 0       10002428  23473524  35479615  226583    600       ml
# 1       10002428  23473524  35479615  226559     60       ml
# 2       10002428  23473524  35479615  226559     45       ml
# 3       10002428  23473524  35479615  226559    125       ml
# 4       10002428  23473524  35479615  226559     60       ml
# ...          ...       ...       ...     ...    ...      ...
# 9357    10016742  29281842  37057036  226559    230       ml
# 9358    10016742  29281842  37057036  226559    120       ml
# 9359    10016742  29281842  37057036  226559    250       ml
# 9360    10016742  29281842  37057036  226559     80       ml
# 9361    10016742  29281842  37057036  226559    160       ml
#
# [9362 rows x 6 columns]

# %%
output_events.equals(h_output_events)
# Out:
# False

# %%
# Not using h_output_events anymore. Redundant

# %%
patients
# Out:
#     subject_id gender  anchor_age  anchor_year anchor_year_group         dod
# 0     10014729      F          21         2125       2011 - 2013         NaN
# 1     10003400      F          72         2134       2011 - 2013  2137-09-02
# 2     10002428      F          80         2155       2011 - 2013         NaN
# 3     10032725      F          38         2143       2011 - 2013  2143-03-30
# 4     10027445      F          48         2142       2011 - 2013  2146-02-09
# ..         ...    ...         ...          ...               ...         ...
# 95    10004733      M          51         2174       2014 - 2016         NaN
# 96    10021118      M          62         2161       2014 - 2016         NaN
# 97    10018501      M          83         2141       2014 - 2016         NaN
# 98    10007058      M          48         2167       2014 - 2016         NaN
# 99    10038992      M          70         2185       2014 - 2016         NaN
#
# [100 rows x 6 columns]

# %%
patients.rename(columns={'dod':"death_flag"}, inplace=True)

# %%
patients['death_flag']=patients['death_flag'].notna().astype(int)

# %%
patients
# Out:
#     subject_id gender  anchor_age  anchor_year anchor_year_group  death_flag
# 0     10014729      F          21         2125       2011 - 2013           0
# 1     10003400      F          72         2134       2011 - 2013           1
# 2     10002428      F          80         2155       2011 - 2013           0
# 3     10032725      F          38         2143       2011 - 2013           1
# 4     10027445      F          48         2142       2011 - 2013           1
# ..         ...    ...         ...          ...               ...         ...
# 95    10004733      M          51         2174       2014 - 2016           0
# 96    10021118      M          62         2161       2014 - 2016           0
# 97    10018501      M          83         2141       2014 - 2016           0
# 98    10007058      M          48         2167       2014 - 2016           0
# 99    10038992      M          70         2185       2014 - 2016           0
#
# [100 rows x 6 columns]

# %%
patients=patients.drop(columns=['anchor_year'])

# %%
patients
# Out:
#     subject_id gender  anchor_age anchor_year_group  death_flag
# 0     10014729      F          21       2011 - 2013           0
# 1     10003400      F          72       2011 - 2013           1
# 2     10002428      F          80       2011 - 2013           0
# 3     10032725      F          38       2011 - 2013           1
# 4     10027445      F          48       2011 - 2013           1
# ..         ...    ...         ...               ...         ...
# 95    10004733      M          51       2014 - 2016           0
# 96    10021118      M          62       2014 - 2016           0
# 97    10018501      M          83       2014 - 2016           0
# 98    10007058      M          48       2014 - 2016           0
# 99    10038992      M          70       2014 - 2016           0
#
# [100 rows x 5 columns]

# %%
# Anchor year is dropped because the data is aggregated by anchor year group.
# DOD was changed to death flag. This is similar to hospital expired flag. Both indicate if a patient had died or not.
# Keeping death flag together so I wouldn't have to join a third data set to get that additional information

# %%
prescriptions
# Out:
#        subject_id   hadm_id  pharmacy_id         poe_id  poe_seq  \
# 0        10027602  28166872     27168639            NaN      NaN
# 1        10027602  28166872     40720238            NaN      NaN
# 2        10027602  28166872     62845687            NaN      NaN
# 3        10027602  28166872     24340150            NaN      NaN
# 4        10027602  28166872     14435820            NaN      NaN
# ...           ...       ...          ...            ...      ...
# 18082    10038081  20755971     33730068   10038081-378    378.0
# 18083    10002428  23473524     87358294   10002428-780    780.0
# 18084    10040025  27996267     81941017  10040025-1640   1640.0
# 18085    10014354  26228185     46019806  10014354-3105   3105.0
# 18086    10004457  25559382     44047546   10004457-443    443.0
#
#       order_provider_id            starttime             stoptime drug_type  \
# 0                   NaN  2201-10-30 12:00:00                  NaN      MAIN
# 1                   NaN  2201-10-30 12:00:00                  NaN      MAIN
# 2                   NaN  2201-10-31 12:00:00                  NaN      MAIN
# 3                   NaN  2201-10-30 12:00:00                  NaN      MAIN
# 4                   NaN  2201-10-30 12:00:00                  NaN      MAIN
# ...                 ...                  ...                  ...       ...
# 18082            P92KOD  2115-10-11 14:00:00  2115-10-13 07:00:00      MAIN
# 18083            P71IN4  2156-05-12 13:00:00  2156-05-22 18:00:00      MAIN
# 18084            P52ORO  2148-01-26 19:00:00  2148-01-26 18:00:00      MAIN
# 18085            P748G6  2150-05-01 01:00:00  2150-05-01 09:00:00      MAIN
# 18086            P65SRP  2148-09-14 17:00:00  2148-09-15 17:00:00      MAIN
#
#                                 drug  ...     gsn           ndc  \
# 0                   Fentanyl Citrate  ...     NaN           NaN
# 1                   Fentanyl Citrate  ...     NaN           NaN
# 2                          Lorazepam  ...     NaN           NaN
# 3                          Midazolam  ...     NaN           NaN
# 4                          Midazolam  ...     NaN           NaN
# ...                              ...  ...     ...           ...
# 18082               Artificial Tears  ...  030016  2.305060e+07
# 18083               Artificial Tears  ...  030016  2.305060e+07
# 18084  OxyCODONE (Immediate Release)  ...  046474  9.046446e+08
# 18085        Carbamide Peroxide 6.5%  ...  008120  7.811207e+10
# 18086                  Acetaminophen  ...  065758  1.211971e+08
#
#             prod_strength form_rx dose_val_rx dose_unit_rx  form_val_disp  \
# 0                     NaN     NaN         NaN          NaN            NaN
# 1                     NaN     NaN         NaN          NaN            NaN
# 2                     NaN     NaN         NaN          NaN            NaN
# 3                     NaN     NaN         NaN          NaN            NaN
# 4                     NaN     NaN         NaN          NaN            NaN
# ...                   ...     ...         ...          ...            ...
# 18082  0.4 mL DROPPERETTE     NaN         1-2         DROP  0.1667-0.3333
# 18083            0.3mL UD     NaN         1-2         DROP  0.1667-0.3333
# 18084         15mg Tablet     NaN        5-10           mg  0.3333-0.6667
# 18085         15mL Bottle     NaN        5-10         DROP  0.3333-0.6667
# 18086        650mg UD Cup     NaN    500-1000           mg  0.7692-1.5385
#
#       form_unit_disp doses_per_24_hrs      route
# 0                NaN              NaN        NaN
# 1                NaN              NaN        NaN
# 2                NaN              NaN        NaN
# 3                NaN              NaN        NaN
# 4                NaN              NaN        NaN
# ...              ...              ...        ...
# 18082            DRP              NaN  BOTH EYES
# 18083            DRP              NaN  BOTH EYES
# 18084            TAB              NaN      PO/NG
# 18085            BTL              1.0  BOTH EARS
# 18086          UDCUP              NaN      PO/NG
#
# [18087 rows x 21 columns]

# %%
prescriptions=prescriptions.drop(columns=['hadm_id','pharmacy_id','poe_id','poe_seq','order_provider_id','starttime','stoptime','gsn','ndc',
                                'prod_strength','form_rx','dose_val_rx','dose_unit_rx','form_val_disp','form_unit_disp','doses_per_24_hrs','route'])

# %%
prescriptions
# Out:
#        subject_id drug_type                           drug formulary_drug_cd
# 0        10027602      MAIN               Fentanyl Citrate            FENT2I
# 1        10027602      MAIN               Fentanyl Citrate            FENT2I
# 2        10027602      MAIN                      Lorazepam            LORA2I
# 3        10027602      MAIN                      Midazolam            MIDA2I
# 4        10027602      MAIN                      Midazolam            MIDA2I
# ...           ...       ...                            ...               ...
# 18082    10038081      MAIN               Artificial Tears           REFRESH
# 18083    10002428      MAIN               Artificial Tears           REFRESH
# 18084    10040025      MAIN  OxyCODONE (Immediate Release)           OXYIR15
# 18085    10014354      MAIN        Carbamide Peroxide 6.5%          GLYO65OT
# 18086    10004457      MAIN                  Acetaminophen          ACET650L
#
# [18087 rows x 4 columns]

# %%
prescriptions['drug']= prescriptions['drug'].str.strip().str.lower()

# %%
presc_agg = prescriptions.groupby('subject_id').agg({
    'drug': lambda x: list(set(x))
}).reset_index()

# %%
# There was a lot of redundant data or data that doesn't align with my granularity so they were removed.

# %%
procedure_code
# Out:
#      subject_id   hadm_id  seq_num   chartdate icd_code  icd_version
# 0      10011398  27505812        3  2146-12-15     3961            9
# 1      10011398  27505812        2  2146-12-15     3615            9
# 2      10011398  27505812        1  2146-12-15     3614            9
# 3      10014729  23300884        4  2125-03-23     3897            9
# 4      10014729  23300884        1  2125-03-20     3403            9
# ..          ...       ...      ...         ...      ...          ...
# 717    10004733  27411876        3  2174-12-20     4513            9
# 718    10021118  24490144        4  2161-11-19  5A1221Z           10
# 719    10021118  24490144        3  2161-11-19  06BP4ZZ           10
# 720    10021118  24490144        1  2161-11-19  02100Z9           10
# 721    10021118  24490144        2  2161-11-19  02110Z3           10
#
# [722 rows x 6 columns]

# %%
procedure_code=procedure_code.drop(columns=['hadm_id','seq_num','chartdate'])

# %%
procedure_code
# Out:
#      subject_id icd_code  icd_version
# 0      10011398     3961            9
# 1      10011398     3615            9
# 2      10011398     3614            9
# 3      10014729     3897            9
# 4      10014729     3403            9
# ..          ...      ...          ...
# 717    10004733     4513            9
# 718    10021118  5A1221Z           10
# 719    10021118  06BP4ZZ           10
# 720    10021118  02100Z9           10
# 721    10021118  02110Z3           10
#
# [722 rows x 3 columns]

# %%
services
# Out:
#      subject_id   hadm_id      transfertime prev_service curr_service
# 0      10001725  25563031   4/11/2110 15:09          NaN          GYN
# 1      10019003  28003918   12/21/2148 3:32          NaN          GYN
# 2      10007818  22987108   6/10/2146 16:38          NaN          MED
# 3      10004235  24181354   2/24/2196 14:39          NaN          MED
# 4      10026255  22059910    7/7/2201 18:16          NaN          MED
# ..          ...       ...               ...          ...          ...
# 314    10005909  20199380  10/28/2144 23:20          NaN        VSURG
# 315    10040025  27996267   1/23/2148 12:18          NaN        VSURG
# 316    10040025  25933959  12/29/2147 19:37          NaN        VSURG
# 317    10040025  27259207   12/4/2147 20:49          NaN        VSURG
# 318    10004457  28108313   12/19/2147 2:11          NaN        VSURG
#
# [319 rows x 5 columns]

# %%
services=services.drop(columns=['hadm_id','transfertime'])

# %%
services["prev_service"] = services["prev_service"].apply(lambda x: None if pd.isna(x) else x)

# %%
services
# Out:
#      subject_id prev_service curr_service
# 0      10001725         None          GYN
# 1      10019003         None          GYN
# 2      10007818         None          MED
# 3      10004235         None          MED
# 4      10026255         None          MED
# ..          ...          ...          ...
# 314    10005909         None        VSURG
# 315    10040025         None        VSURG
# 316    10040025         None        VSURG
# 317    10040025         None        VSURG
# 318    10004457         None        VSURG
#
# [319 rows x 3 columns]

# %%
transfers
# Out:
#       subject_id     hadm_id  transfer_id  eventtype  \
# 0       10009049  22995465.0     30030230  discharge
# 1       10025612  23403708.0     32533329  discharge
# 2       10020786  23488445.0     37922399  discharge
# 3       10014078  25809882.0     34694622  discharge
# 4       10039831  26924951.0     37155928  discharge
# ...          ...         ...          ...        ...
# 1185    10021118  24490144.0     31983963   transfer
# 1186    10021118  24490144.0     38367109   transfer
# 1187    10021118  24490144.0     39362807   transfer
# 1188    10021118  24490144.0     38425947      admit
# 1189    10021118  24490144.0     36558922   transfer
#
#                                           careunit               intime  \
# 0                                              NaN  2174-05-31 14:21:47
# 1                                              NaN  2125-10-03 12:25:27
# 2                                              NaN  2189-06-13 17:25:44
# 3                                              NaN  2166-08-26 14:49:42
# 4                                              NaN  2116-01-02 14:35:02
# ...                                            ...                  ...
# 1185                                          PACU  2161-11-19 07:16:15
# 1186                               Cardiac Surgery  2161-11-20 21:45:42
# 1187                           Medicine/Cardiology  2161-11-16 19:53:20
# 1188                           Medicine/Cardiology  2161-11-15 20:10:55
# 1189  Cardiac Vascular Intensive Care Unit (CVICU)  2161-11-19 10:04:04
#
#                   outtime
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 1185  2161-11-19 10:04:04
# 1186  2161-11-23 16:06:31
# 1187  2161-11-19 07:16:15
# 1188  2161-11-16 19:53:20
# 1189  2161-11-20 21:45:42
#
# [1190 rows x 7 columns]

# %%
transfers=transfers.drop(columns=['hadm_id','intime','outtime'])

# %%
# not dropping careunit. NAN mean that the patient was discharged and no longer under the hospitals care

# %% [markdown]
# # Joining data sets

# %%
# Joined Diagnoses
j_diagnoses=diagnoses.merge(diagnoses_code,on=['icd_code','icd_version'],how='inner')

# Joined Procedure Events
j_procedure_code=procedure_code.merge(d_procedure_code,on=['icd_code','icd_version'],how='inner')

# %%
j_diagnoses
# Out:
#       subject_id icd_code  icd_version  \
# 0       10035185     4139            9
# 1       10005348     4139            9
# 2       10035185     V707            9
# 3       10012552     V707            9
# 4       10005817     V707            9
# ...          ...      ...          ...
# 4501    10004733    E9383            9
# 4502    10004733    34290            9
# 4503    10004733    40300            9
# 4504    10004733     0416            9
# 4505    10004733     3129            9
#
#                                              long_title
# 0                 other and unspecified angina pectoris
# 1                 other and unspecified angina pectoris
# 2          examination of participant in clinical trial
# 3          examination of participant in clinical trial
# 4          examination of participant in clinical trial
# ...                                                 ...
# 4501  intravenous anesthetics causing adverse effect...
# 4502  hemiplegia, unspecified, affecting unspecified...
# 4503  hypertensive chronic kidney disease, malignant...
# 4504  proteus (mirabilis) (morganii) infection in co...
# 4505                 unspecified disturbance of conduct
#
# [4506 rows x 4 columns]

# %%
j_diagnoses=j_diagnoses.drop(columns=['icd_code','icd_version'])

# %%
diag_agg = j_diagnoses.groupby('subject_id').agg({
    'long_title': lambda x: list(set(x))
}).reset_index()

# %%
diag_agg
# Out:
#     subject_id                                         long_title
# 0     10000032  [diarrhea, tobacco use disorder, other iatroge...
# 1     10001217  [intracranial abscess, pulmonary collapse, str...
# 2     10001725  [vaginal enterocele, congenital or acquired, m...
# 3     10002428  [age-related osteoporosis with current patholo...
# 4     10002495  [unspecified injury of urethra, initial encoun...
# ..         ...                                                ...
# 95    10038999  [unspecified place in other specified resident...
# 96    10039708  [hyperosmolality and hypernatremia, hypotensio...
# 97    10039831  [accidental cut, puncture, perforation or hemo...
# 98    10039997  [hemiplegia, unspecified affecting right domin...
# 99    10040025  [type 2 diabetes mellitus with diabetic chroni...
#
# [100 rows x 2 columns]

# %%
diag_agg.rename(columns={'long_title':'diagnoses_name'}, inplace=True)

# %%
diag_exploded=diag_agg.explode('diagnoses_name')

diagnosis_counts = (
    diag_exploded['diagnoses_name']
        .str.lower()                     # normalize text
        .value_counts()                  # count occurrences
        .reset_index()
        .rename(columns={'index': 'diagnoses_name', 'diagnoses_name': 'count'})
)

# %%
j_procedure_code
# Out:
#      subject_id icd_code  icd_version  \
# 0      10011398     3961            9
# 1      10014729     3961            9
# 2      10009628     3961            9
# 3      10005817     3961            9
# 4      10023771     3961            9
# ..          ...      ...          ...
# 717    10025463     0096            9
# 718    10002428     9390            9
# 719    10004733     3322            9
# 720    10004733     5523            9
# 721    10021118  02110Z3           10
#
#                                             long_title
# 0    extracorporeal circulation auxiliary to open h...
# 1    extracorporeal circulation auxiliary to open h...
# 2    extracorporeal circulation auxiliary to open h...
# 3    extracorporeal circulation auxiliary to open h...
# 4    extracorporeal circulation auxiliary to open h...
# ..                                                 ...
# 717  infusion of 4-factor prothrombin complex conce...
# 718                non-invasive mechanical ventilation
# 719                           fiber-optic bronchoscopy
# 720    closed [percutaneous] [needle] biopsy of kidney
# 721  bypass coronary artery, two arteries from coro...
#
# [722 rows x 4 columns]

# %%
proc_agg
# Out:
#     subject_id                                  ordercategoryname  \
# 0     10000032                     [peripheral lines, procedures]
# 1     10001217  [imaging, invasive lines, peripheral lines, co...
# 2     10001725                                 [peripheral lines]
# 3     10002428  [communication, ventilation, imaging, intubati...
# 4     10002495  [communication, ventilation, imaging, tubes, p...
# ..         ...                                                ...
# 95    10038999  [communication, ventilation, imaging, tubes, i...
# 96    10039708  [ventilation, imaging, tubes, intubation/extub...
# 97    10039831  [imaging, invasive lines, peripheral lines, pr...
# 98    10039997        [imaging, invasive lines, peripheral lines]
# 99    10040025  [ventilation, imaging, tubes, intubation/extub...
#
#      ordercategorydescription
# 0   [task, continuousprocess]
# 1   [task, continuousprocess]
# 2         [continuousprocess]
# 3   [task, continuousprocess]
# 4   [task, continuousprocess]
# ..                        ...
# 95  [task, continuousprocess]
# 96  [task, continuousprocess]
# 97  [task, continuousprocess]
# 98  [task, continuousprocess]
# 99  [task, continuousprocess]
#
# [100 rows x 3 columns]

# %%
j_procedure_code
# Out:
#      subject_id icd_code  icd_version  \
# 0      10011398     3961            9
# 1      10014729     3961            9
# 2      10009628     3961            9
# 3      10005817     3961            9
# 4      10023771     3961            9
# ..          ...      ...          ...
# 717    10025463     0096            9
# 718    10002428     9390            9
# 719    10004733     3322            9
# 720    10004733     5523            9
# 721    10021118  02110Z3           10
#
#                                             long_title
# 0    extracorporeal circulation auxiliary to open h...
# 1    extracorporeal circulation auxiliary to open h...
# 2    extracorporeal circulation auxiliary to open h...
# 3    extracorporeal circulation auxiliary to open h...
# 4    extracorporeal circulation auxiliary to open h...
# ..                                                 ...
# 717  infusion of 4-factor prothrombin complex conce...
# 718                non-invasive mechanical ventilation
# 719                           fiber-optic bronchoscopy
# 720    closed [percutaneous] [needle] biopsy of kidney
# 721  bypass coronary artery, two arteries from coro...
#
# [722 rows x 4 columns]

# %%
j_procedure_code=j_procedure_code.drop(columns=['icd_code','icd_version'])

# %%
procedure_agg = j_procedure_code.groupby('subject_id').agg({
    'long_title': lambda x: list(set(x))
}).reset_index()

# %%
procedure_agg.rename(columns={'long_title':'procedure_name'}, inplace=True)

# %%
procedure_agg
# Out:
#     subject_id                                     procedure_name
# 0     10000032                  [percutaneous abdominal drainage]
# 1     10001217  [central venous catheter placement with guidan...
# 2     10001725  [repair of rectocele with graft or prosthesis,...
# 3     10002428  [insertion of endotracheal tube, arterial cath...
# 4     10002495  [fluoroscopy of multiple coronary arteries usi...
# ..         ...                                                ...
# 87    10038999  [introduction of nutritional substance into lo...
# 88    10039708  [introduction of nutritional substance into lo...
# 89    10039831  [repair of blood vessel with tissue patch graf...
# 90    10039997  [other computer assisted surgery, clipping of ...
# 91    10040025  [transfusion of nonautologous 4-factor prothro...
#
# [92 rows x 2 columns]

# %%
output_d=output_events.merge(d_items,on=['itemid'], how='inner')

# %%
output_d
# Out:
#       subject_id   stay_id  itemid  value valueuom        label category
# 0       10002428  35479615  226583    600       ml  Rectal Tube   Output
# 1       10029291  35146796  226583    225       ml  Rectal Tube   Output
# 2       10029291  35146796  226583    100       ml  Rectal Tube   Output
# 3       10029291  35146796  226583    450       ml  Rectal Tube   Output
# 4       10002428  35479615  226583    200       ml  Rectal Tube   Output
# ...          ...       ...     ...    ...      ...          ...      ...
# 9357    10031404  35544374  226612    220       ml  Pericardial   Drains
# 9358    10031404  35544374  226612     75       ml  Pericardial   Drains
# 9359    10038999  39711498  226612     30       ml  Pericardial   Drains
# 9360    10014354  38017367  226612     10       ml  Pericardial   Drains
# 9361    10025463  38275267  226628     48       ml  PACU Drains   Output
#
# [9362 rows x 7 columns]

# %%
#aggregating variables by subject_id

output_agg = output_d.groupby('subject_id').agg({
    'value': lambda x: list(set(x)),
    'valueuom': lambda x: list(set(x)),
    'label': lambda x: list(set(x)),
    'category': lambda x: list(set(x))
}).reset_index()

# %%
output_agg
# Out:
#     subject_id                                              value valueuom  \
# 0     10000032                                              [175]     [ml]
# 1     10001217  [225, 450, 900, 100, 200, 650, 300, 400, 275, ...     [ml]
# 2     10001725  [160, 100, 170, 75, 300, 175, 15, 50, 150, 375...     [ml]
# 3     10002428  [0, 130, 260, 5, 6, 135, 7, 10, 140, 525, 270,...     [ml]
# 4     10002495  [0, 135, 270, 400, 3600, 20, 150, 25, 30, 40, ...     [ml]
# ..         ...                                                ...      ...
# 95    10038999  [130, 8, 10, 650, 140, 15, 400, 20, 150, 25, 3...     [ml]
# 96    10039708  [0, 130, 5, 8, 10, 12, 140, 15, 16, 145, 18, 2...     [ml]
# 97    10039831  [260, 270, 400, 150, 30, 160, 40, 300, 45, 50,...     [ml]
# 98    10039997   [450, 200, 650, 75, 50, 85, 150, 3000, 125, 350]     [ml]
# 99    10040025  [130, 5, 135, 10, 140, 15, 20, 150, 25, 30, 32...     [ml]
#
#                                                 label          category
# 0                                              [Void]          [Output]
# 1                                      [Emesis, Void]          [Output]
# 2                                             [Foley]          [Output]
# 3   [Pre-Admission, Foley, Pigtail #1, Chest Tube ...  [Drains, Output]
# 4   [GU Irrigant/Urine Volume Out, GU Irrigant Vol...          [Output]
# ..                                                ...               ...
# 95                 [Pericardial, L Pleural #1, Foley]  [Drains, Output]
# 96      [TF Residual, Fecal Bag, Oral Gastric, Foley]          [Output]
# 97                          [OR Urine, OR EBL, Foley]          [Output]
# 98                    [OR EBL, Void, OR Urine, Foley]          [Output]
# 99  [Wound Vac #1, Foley, OR Urine, Fecal Bag, Stool]  [Drains, Output]
#
# [100 rows x 5 columns]

# %% [markdown]
# # Joining more datasets.
#
# The datasets had to be joined and cleaned before I could join them to the rest of the data

# %%
# Demographs (Combination of ICU stays, Patients, admin)

# Can then add another variable which is demograhics (Age, Status, language, race, Insurance)

# Demo_diag (Demographics+Diagnoses)
# Diagnoses + First Care + LOS
# Diagnoses + First Care + Death_Flag

# Demo_dipro (Demographics+Diagnones+Procedure)
# Diagnoses + Procedure + LOS
# Diagnoses + Procedure + Death_Flag

# Demo_out (Demographics+Output)
# Item_ID + Value + LOS
# Item_ID + Value + Death_Flag

#Demo_Diout (Demographics+Diagnoses+Output)
# Item_ID + Value + Diagnosis + LOS
# Item_ID + Value + Diagnosis + Death_flag

#Demo_care
#Prescription + Diagnosis + Procedure + LOS
#Prescription + Diagnosis + Procedure + Diagnosis

# %%
patient_admin=patients.merge(adm_agg,on=['subject_id'],how='inner')

# %%
patient_admin
# Out:
#     subject_id gender  anchor_age anchor_year_group  death_flag   insurance  \
# 0     10014729      F          21       2011 - 2013           0     [other]
# 1     10003400      F          72       2011 - 2013           1  [medicare]
# 2     10002428      F          80       2011 - 2013           0  [medicare]
# 3     10032725      F          38       2011 - 2013           1     [other]
# 4     10027445      F          48       2011 - 2013           1     [other]
# ..         ...    ...         ...               ...         ...         ...
# 95    10004733      M          51       2014 - 2016           0  [medicaid]
# 96    10021118      M          62       2014 - 2016           0     [other]
# 97    10018501      M          83       2014 - 2016           0  [medicare]
# 98    10007058      M          48       2014 - 2016           0     [other]
# 99    10038992      M          70       2014 - 2016           0  [medicare]
#
#      language marital_status                      race
# 0   [english]       [single]  [white - other european]
# 1   [english]      [married]  [black/african american]
# 2   [english]      [widowed]                   [white]
# 3   [english]       [single]  [black/african american]
# 4   [english]      [widowed]                   [white]
# ..        ...            ...                       ...
# 95  [english]       [single]                 [unknown]
# 96  [english]      [married]                   [white]
# 97  [english]          [nan]                   [white]
# 98  [english]      [married]                   [white]
# 99  [english]      [married]          [white, unknown]
#
# [100 rows x 9 columns]

# %%
demographics=icu_stays.merge(patient_admin,on=['subject_id'], how='inner')

# %%
demographics
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 135    10023239  35024147  medical/surgical intensive care unit (micu/sicu)
# 136    10001725  31205490  medical/surgical intensive care unit (micu/sicu)
# 137    10035631  30932571  medical/surgical intensive care unit (micu/sicu)
# 138    10020786  33683112  medical/surgical intensive care unit (micu/sicu)
# 139    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
#
#            los gender  anchor_age anchor_year_group  death_flag  \
# 0     7.702512      F          83       2014 - 2016           0
# 1     5.452662      F          63       2014 - 2016           0
# 2     0.872685      F          63       2014 - 2016           0
# 3     3.766725      F          91       2014 - 2016           0
# 4     1.037106      M          56       2014 - 2016           0
# ..         ...    ...         ...               ...         ...
# 135   2.432998      F          29       2014 - 2016           0
# 136   1.338588      F          46       2011 - 2013           0
# 137  10.494259      M          63       2011 - 2013           1
# 138   1.424757      F          86       2014 - 2016           0
# 139   3.349687      F          38       2011 - 2013           1
#
#              insurance   language     marital_status  \
# 0              [other]  [english]         [divorced]
# 1              [other]        [?]          [married]
# 2              [other]        [?]          [married]
# 3    [medicare, other]  [english]          [widowed]
# 4              [other]  [english]           [single]
# ..                 ...        ...                ...
# 135            [other]  [english]  [married, single]
# 136            [other]  [english]          [married]
# 137            [other]  [english]          [married]
# 138         [medicare]  [english]          [widowed]
# 139            [other]  [english]           [single]
#
#                                race
# 0                           [white]
# 1    [hispanic/latino - salvadoran]
# 2    [hispanic/latino - salvadoran]
# 3          [black/african american]
# 4                           [white]
# ..                              ...
# 135                         [white]
# 136                         [white]
# 137                [white, unknown]
# 138                         [white]
# 139        [black/african american]
#
# [140 rows x 12 columns]

# %%
demo_diag=demographics.merge(diag_agg,on=['subject_id'],how='inner')

# %%
demo_diag
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 135    10023239  35024147  medical/surgical intensive care unit (micu/sicu)
# 136    10001725  31205490  medical/surgical intensive care unit (micu/sicu)
# 137    10035631  30932571  medical/surgical intensive care unit (micu/sicu)
# 138    10020786  33683112  medical/surgical intensive care unit (micu/sicu)
# 139    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
#
#            los gender  anchor_age anchor_year_group  death_flag  \
# 0     7.702512      F          83       2014 - 2016           0
# 1     5.452662      F          63       2014 - 2016           0
# 2     0.872685      F          63       2014 - 2016           0
# 3     3.766725      F          91       2014 - 2016           0
# 4     1.037106      M          56       2014 - 2016           0
# ..         ...    ...         ...               ...         ...
# 135   2.432998      F          29       2014 - 2016           0
# 136   1.338588      F          46       2011 - 2013           0
# 137  10.494259      M          63       2011 - 2013           1
# 138   1.424757      F          86       2014 - 2016           0
# 139   3.349687      F          38       2011 - 2013           1
#
#              insurance   language     marital_status  \
# 0              [other]  [english]         [divorced]
# 1              [other]        [?]          [married]
# 2              [other]        [?]          [married]
# 3    [medicare, other]  [english]          [widowed]
# 4              [other]  [english]           [single]
# ..                 ...        ...                ...
# 135            [other]  [english]  [married, single]
# 136            [other]  [english]          [married]
# 137            [other]  [english]          [married]
# 138         [medicare]  [english]          [widowed]
# 139            [other]  [english]           [single]
#
#                                race  \
# 0                           [white]
# 1    [hispanic/latino - salvadoran]
# 2    [hispanic/latino - salvadoran]
# 3          [black/african american]
# 4                           [white]
# ..                              ...
# 135                         [white]
# 136                         [white]
# 137                [white, unknown]
# 138                         [white]
# 139        [black/african american]
#
#                                         diagnoses_name
# 0    [supermarket, store or market as the place of ...
# 1    [presence of right artificial knee joint, pure...
# 2    [presence of right artificial knee joint, pure...
# 3    [long-term (current) use of anticoagulants, co...
# 4    [pneumonitis due to inhalation of food or vomi...
# ..                                                 ...
# 135  [mechanical complication due to insulin pump, ...
# 136  [vaginal enterocele, congenital or acquired, m...
# 137  [diarrhea, hepatitis, unspecified, graft-versu...
# 138  [unspecified atrial fibrillation, chronic obst...
# 139  [secondary malignant neoplasm of brain and spi...
#
# [140 rows x 13 columns]

# %%
demo_dipro=demo_diag.merge(procedure_agg,on=['subject_id'], how='inner')

# %%
demo_dipro
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 126    10023239  33846653  medical/surgical intensive care unit (micu/sicu)
# 127    10023239  35024147  medical/surgical intensive care unit (micu/sicu)
# 128    10001725  31205490  medical/surgical intensive care unit (micu/sicu)
# 129    10035631  30932571  medical/surgical intensive care unit (micu/sicu)
# 130    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
#
#            los gender  anchor_age anchor_year_group  death_flag  \
# 0     7.702512      F          83       2014 - 2016           0
# 1     5.452662      F          63       2014 - 2016           0
# 2     0.872685      F          63       2014 - 2016           0
# 3     3.766725      F          91       2014 - 2016           0
# 4     1.037106      M          56       2014 - 2016           0
# ..         ...    ...         ...               ...         ...
# 126   2.825370      F          29       2014 - 2016           0
# 127   2.432998      F          29       2014 - 2016           0
# 128   1.338588      F          46       2011 - 2013           0
# 129  10.494259      M          63       2011 - 2013           1
# 130   3.349687      F          38       2011 - 2013           1
#
#              insurance   language     marital_status  \
# 0              [other]  [english]         [divorced]
# 1              [other]        [?]          [married]
# 2              [other]        [?]          [married]
# 3    [medicare, other]  [english]          [widowed]
# 4              [other]  [english]           [single]
# ..                 ...        ...                ...
# 126            [other]  [english]  [married, single]
# 127            [other]  [english]  [married, single]
# 128            [other]  [english]          [married]
# 129            [other]  [english]          [married]
# 130            [other]  [english]           [single]
#
#                                race  \
# 0                           [white]
# 1    [hispanic/latino - salvadoran]
# 2    [hispanic/latino - salvadoran]
# 3          [black/african american]
# 4                           [white]
# ..                              ...
# 126                         [white]
# 127                         [white]
# 128                         [white]
# 129                [white, unknown]
# 130        [black/african american]
#
#                                         diagnoses_name  \
# 0    [supermarket, store or market as the place of ...
# 1    [presence of right artificial knee joint, pure...
# 2    [presence of right artificial knee joint, pure...
# 3    [long-term (current) use of anticoagulants, co...
# 4    [pneumonitis due to inhalation of food or vomi...
# ..                                                 ...
# 126  [mechanical complication due to insulin pump, ...
# 127  [mechanical complication due to insulin pump, ...
# 128  [vaginal enterocele, congenital or acquired, m...
# 129  [diarrhea, hepatitis, unspecified, graft-versu...
# 130  [secondary malignant neoplasm of brain and spi...
#
#                                         procedure_name
# 0    [restriction of intracranial artery with intra...
# 1    [restriction of intracranial artery with intra...
# 2    [restriction of intracranial artery with intra...
# 3    [assistance with respiratory ventilation, grea...
# 4    [laparoscopic partial cholecystectomy, inserti...
# ..                                                 ...
# 126  [excision of right middle lung lobe, via natur...
# 127  [excision of right middle lung lobe, via natur...
# 128  [repair of rectocele with graft or prosthesis,...
# 129  [transplant from live related donor, biopsy of...
# 130  [insertion of endotracheal tube, continuous in...
#
# [131 rows x 14 columns]

# %%
demo_out=demographics.merge(output_agg,on=['subject_id'],how='inner')

# %%
demo_out
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 135    10023239  35024147  medical/surgical intensive care unit (micu/sicu)
# 136    10001725  31205490  medical/surgical intensive care unit (micu/sicu)
# 137    10035631  30932571  medical/surgical intensive care unit (micu/sicu)
# 138    10020786  33683112  medical/surgical intensive care unit (micu/sicu)
# 139    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
#
#            los gender  anchor_age anchor_year_group  death_flag  \
# 0     7.702512      F          83       2014 - 2016           0
# 1     5.452662      F          63       2014 - 2016           0
# 2     0.872685      F          63       2014 - 2016           0
# 3     3.766725      F          91       2014 - 2016           0
# 4     1.037106      M          56       2014 - 2016           0
# ..         ...    ...         ...               ...         ...
# 135   2.432998      F          29       2014 - 2016           0
# 136   1.338588      F          46       2011 - 2013           0
# 137  10.494259      M          63       2011 - 2013           1
# 138   1.424757      F          86       2014 - 2016           0
# 139   3.349687      F          38       2011 - 2013           1
#
#              insurance   language     marital_status  \
# 0              [other]  [english]         [divorced]
# 1              [other]        [?]          [married]
# 2              [other]        [?]          [married]
# 3    [medicare, other]  [english]          [widowed]
# 4              [other]  [english]           [single]
# ..                 ...        ...                ...
# 135            [other]  [english]  [married, single]
# 136            [other]  [english]          [married]
# 137            [other]  [english]          [married]
# 138         [medicare]  [english]          [widowed]
# 139            [other]  [english]           [single]
#
#                                race  \
# 0                           [white]
# 1    [hispanic/latino - salvadoran]
# 2    [hispanic/latino - salvadoran]
# 3          [black/african american]
# 4                           [white]
# ..                              ...
# 135                         [white]
# 136                         [white]
# 137                [white, unknown]
# 138                         [white]
# 139        [black/african american]
#
#                                                  value valueuom  \
# 0    [0, 1, 130, 650, 140, 400, 150, 25, 30, 160, 3...     [ml]
# 1    [0, 900, 400, 1300, 150, 30, 160, 800, 550, 30...     [ml]
# 2    [0, 900, 400, 1300, 150, 30, 160, 800, 550, 30...     [ml]
# 3    [260, 135, 15, 20, 150, 25, 30, 35, 40, 300, 4...     [ml]
# 4    [0, 130, 5, 265, 10, 400, 275, 20, 150, 280, 2...     [ml]
# ..                                                 ...      ...
# 135           [0, 800, 900, 1000, 1100, 850, 600, 700]     [ml]
# 136  [160, 100, 170, 75, 300, 175, 15, 50, 150, 375...     [ml]
# 137  [0, 130, 2, 390, 10, 140, 15, 20, 150, 25, 155...     [ml]
# 138                                [200, 25, 400, 150]     [ml]
# 139  [13, 15, 150, 25, 30, 37, 40, 45, 50, 51, 60, ...     [ml]
#
#                                                  label          category
# 0                                        [Void, Foley]          [Output]
# 1                  [PACU Urine, Void, OR Urine, Foley]          [Output]
# 2                  [PACU Urine, Void, OR Urine, Foley]          [Output]
# 3                               [Pre-Admission, Foley]          [Output]
# 4    [Void, Emesis, Jackson Pratt #1, Oral Gastric,...  [Drains, Output]
# ..                                                 ...               ...
# 135                                             [Void]          [Output]
# 136                                            [Foley]          [Output]
# 137            [Condom Cath, TF Residual, Void, Foley]          [Output]
# 138                              [Pre-Admission, Void]          [Output]
# 139                             [Pre-Admission, Foley]          [Output]
#
# [140 rows x 16 columns]

# %%
demo_diout=demo_out.merge(diag_agg,on=['subject_id'], how='inner')

# %%
demo_diout
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 135    10023239  35024147  medical/surgical intensive care unit (micu/sicu)
# 136    10001725  31205490  medical/surgical intensive care unit (micu/sicu)
# 137    10035631  30932571  medical/surgical intensive care unit (micu/sicu)
# 138    10020786  33683112  medical/surgical intensive care unit (micu/sicu)
# 139    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
#
#            los gender  anchor_age anchor_year_group  death_flag  \
# 0     7.702512      F          83       2014 - 2016           0
# 1     5.452662      F          63       2014 - 2016           0
# 2     0.872685      F          63       2014 - 2016           0
# 3     3.766725      F          91       2014 - 2016           0
# 4     1.037106      M          56       2014 - 2016           0
# ..         ...    ...         ...               ...         ...
# 135   2.432998      F          29       2014 - 2016           0
# 136   1.338588      F          46       2011 - 2013           0
# 137  10.494259      M          63       2011 - 2013           1
# 138   1.424757      F          86       2014 - 2016           0
# 139   3.349687      F          38       2011 - 2013           1
#
#              insurance   language     marital_status  \
# 0              [other]  [english]         [divorced]
# 1              [other]        [?]          [married]
# 2              [other]        [?]          [married]
# 3    [medicare, other]  [english]          [widowed]
# 4              [other]  [english]           [single]
# ..                 ...        ...                ...
# 135            [other]  [english]  [married, single]
# 136            [other]  [english]          [married]
# 137            [other]  [english]          [married]
# 138         [medicare]  [english]          [widowed]
# 139            [other]  [english]           [single]
#
#                                race  \
# 0                           [white]
# 1    [hispanic/latino - salvadoran]
# 2    [hispanic/latino - salvadoran]
# 3          [black/african american]
# 4                           [white]
# ..                              ...
# 135                         [white]
# 136                         [white]
# 137                [white, unknown]
# 138                         [white]
# 139        [black/african american]
#
#                                                  value valueuom  \
# 0    [0, 1, 130, 650, 140, 400, 150, 25, 30, 160, 3...     [ml]
# 1    [0, 900, 400, 1300, 150, 30, 160, 800, 550, 30...     [ml]
# 2    [0, 900, 400, 1300, 150, 30, 160, 800, 550, 30...     [ml]
# 3    [260, 135, 15, 20, 150, 25, 30, 35, 40, 300, 4...     [ml]
# 4    [0, 130, 5, 265, 10, 400, 275, 20, 150, 280, 2...     [ml]
# ..                                                 ...      ...
# 135           [0, 800, 900, 1000, 1100, 850, 600, 700]     [ml]
# 136  [160, 100, 170, 75, 300, 175, 15, 50, 150, 375...     [ml]
# 137  [0, 130, 2, 390, 10, 140, 15, 20, 150, 25, 155...     [ml]
# 138                                [200, 25, 400, 150]     [ml]
# 139  [13, 15, 150, 25, 30, 37, 40, 45, 50, 51, 60, ...     [ml]
#
#                                                  label          category  \
# 0                                        [Void, Foley]          [Output]
# 1                  [PACU Urine, Void, OR Urine, Foley]          [Output]
# 2                  [PACU Urine, Void, OR Urine, Foley]          [Output]
# 3                               [Pre-Admission, Foley]          [Output]
# 4    [Void, Emesis, Jackson Pratt #1, Oral Gastric,...  [Drains, Output]
# ..                                                 ...               ...
# 135                                             [Void]          [Output]
# 136                                            [Foley]          [Output]
# 137            [Condom Cath, TF Residual, Void, Foley]          [Output]
# 138                              [Pre-Admission, Void]          [Output]
# 139                             [Pre-Admission, Foley]          [Output]
#
#                                         diagnoses_name
# 0    [supermarket, store or market as the place of ...
# 1    [presence of right artificial knee joint, pure...
# 2    [presence of right artificial knee joint, pure...
# 3    [long-term (current) use of anticoagulants, co...
# 4    [pneumonitis due to inhalation of food or vomi...
# ..                                                 ...
# 135  [mechanical complication due to insulin pump, ...
# 136  [vaginal enterocele, congenital or acquired, m...
# 137  [diarrhea, hepatitis, unspecified, graft-versu...
# 138  [unspecified atrial fibrillation, chronic obst...
# 139  [secondary malignant neoplasm of brain and spi...
#
# [140 rows x 17 columns]

# %%
demo_care=demo_dipro.merge(presc_agg,on=['subject_id'], how='inner')

# %%
demo_care
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 126    10023239  33846653  medical/surgical intensive care unit (micu/sicu)
# 127    10023239  35024147  medical/surgical intensive care unit (micu/sicu)
# 128    10001725  31205490  medical/surgical intensive care unit (micu/sicu)
# 129    10035631  30932571  medical/surgical intensive care unit (micu/sicu)
# 130    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
#
#            los gender  anchor_age anchor_year_group  death_flag  \
# 0     7.702512      F          83       2014 - 2016           0
# 1     5.452662      F          63       2014 - 2016           0
# 2     0.872685      F          63       2014 - 2016           0
# 3     3.766725      F          91       2014 - 2016           0
# 4     1.037106      M          56       2014 - 2016           0
# ..         ...    ...         ...               ...         ...
# 126   2.825370      F          29       2014 - 2016           0
# 127   2.432998      F          29       2014 - 2016           0
# 128   1.338588      F          46       2011 - 2013           0
# 129  10.494259      M          63       2011 - 2013           1
# 130   3.349687      F          38       2011 - 2013           1
#
#              insurance   language     marital_status  \
# 0              [other]  [english]         [divorced]
# 1              [other]        [?]          [married]
# 2              [other]        [?]          [married]
# 3    [medicare, other]  [english]          [widowed]
# 4              [other]  [english]           [single]
# ..                 ...        ...                ...
# 126            [other]  [english]  [married, single]
# 127            [other]  [english]  [married, single]
# 128            [other]  [english]          [married]
# 129            [other]  [english]          [married]
# 130            [other]  [english]           [single]
#
#                                race  \
# 0                           [white]
# 1    [hispanic/latino - salvadoran]
# 2    [hispanic/latino - salvadoran]
# 3          [black/african american]
# 4                           [white]
# ..                              ...
# 126                         [white]
# 127                         [white]
# 128                         [white]
# 129                [white, unknown]
# 130        [black/african american]
#
#                                         diagnoses_name  \
# 0    [supermarket, store or market as the place of ...
# 1    [presence of right artificial knee joint, pure...
# 2    [presence of right artificial knee joint, pure...
# 3    [long-term (current) use of anticoagulants, co...
# 4    [pneumonitis due to inhalation of food or vomi...
# ..                                                 ...
# 126  [mechanical complication due to insulin pump, ...
# 127  [mechanical complication due to insulin pump, ...
# 128  [vaginal enterocele, congenital or acquired, m...
# 129  [diarrhea, hepatitis, unspecified, graft-versu...
# 130  [secondary malignant neoplasm of brain and spi...
#
#                                         procedure_name  \
# 0    [restriction of intracranial artery with intra...
# 1    [restriction of intracranial artery with intra...
# 2    [restriction of intracranial artery with intra...
# 3    [assistance with respiratory ventilation, grea...
# 4    [laparoscopic partial cholecystectomy, inserti...
# ..                                                 ...
# 126  [excision of right middle lung lobe, via natur...
# 127  [excision of right middle lung lobe, via natur...
# 128  [repair of rectocele with graft or prosthesis,...
# 129  [transplant from live related donor, biopsy of...
# 130  [insertion of endotracheal tube, continuous in...
#
#                                                   drug
# 0    [vitamin d, levetiracetam, pravastatin, iso-os...
# 1    [levetiracetam, iso-osmotic sodium chloride, h...
# 2    [levetiracetam, iso-osmotic sodium chloride, h...
# 3    [levothyroxine sodium, vitamin d, multivitamin...
# 4    [chlorhexidine gluconate 0.12% oral rinse, pot...
# ..                                                 ...
# 126  [levothyroxine sodium, insulin human regular, ...
# 127  [levothyroxine sodium, insulin human regular, ...
# 128  [metolazone, iso-osmotic sodium chloride, albu...
# 129  [chlorhexidine gluconate 0.12% oral rinse, vit...
# 130  [carboplatin, nystatin, multivitamins, levetir...
#
# [131 rows x 15 columns]

# %%
# Is the patient eldery
demo_care['is_elderly']= demo_care['anchor_age'] >= 65

# Length of stay in hours (Slightly more precise)
demo_care['los_hours']=demo_care['los']*24

# Did the patient have a long stay. Anything over a week
demo_care['long_stay_flag']=demo_care['los']>7

# Did a patient die within 24 hours?
demo_care['death_within_24h_flag'] = ((demo_care['los_hours'] <= 24) & (demo_care['death_flag'] == 1)).astype(int)

# Does the patient have diabetes?
demo_care['has_diabetes']=demo_care['diagnoses_name'].apply(
    lambda x: any('diabetes' in d.lower() for d in x) if isinstance(x, list) else False)

# Does the patient have any heart issues
demo_care['has_cardiac_issues']=demo_care['diagnoses_name'].apply(
    lambda x: any(any(k in d.lower() for k in ['heart','cardiac','coronary'])for d in x)if isinstance(x, list) else False)

# Diagnoses per patient
demo_care['num_diagnoses'] = demo_care['diagnoses_name'].apply(lambda x: len(set(x)) if isinstance(x, list) else 0)
# Procedures per patient
demo_care['num_procedures'] = demo_care['procedure_name'].apply(lambda x: len(set(x)) if isinstance(x, list) else 0)
# Drugs per patient
demo_care['num_drugs'] = demo_care['drug'].apply(
    lambda x: len(set([d.lower().strip() for d in x])) if isinstance(x, list) else 0
)



# Was the patient readmitted to the hospital
readmission_flag=( demo_care.groupby('subject_id')['stay_id']
                 .transform('count')>1)

demo_care['readmission_flag']=readmission_flag

# encoding ICU Type
le= LabelEncoder()
demo_care['icu_type_encoded']=le.fit_transform(demo_care['first_careunit'].astype(str))

#encoding gender
demo_care['gender']=le.fit_transform(demo_care['gender'].astype(str))

# Encoding anchor_year_group
demo_care['anchor_year_group']=le.fit_transform(demo_care['anchor_year_group'].astype(str))

#encoding language
demo_care['language']=le.fit_transform(demo_care['language'].astype(str))

# Encoding insurance
demo_care['insurance']=le.fit_transform(demo_care['insurance'].astype(str))

#Encoding Readmission Flag
demo_care['readmission_flag']=le.fit_transform(demo_care['readmission_flag'].astype(str))

#Encoding has_cardiac_issue
demo_care['has_cardiac_issues']=le.fit_transform(demo_care['has_cardiac_issues'].astype(str))

#encoding race
demo_care['race']=le.fit_transform(demo_care['race'].astype(str))

#encoding marital_status
demo_care['marital_status']=le.fit_transform(demo_care['marital_status'].astype(str))

# Mortality rate by ICU unit
mortality_rate=( demo_care.groupby('first_careunit')['death_flag']
               .mean()
               .to_dict())

demo_care['mortality_rate_by_unit']=demo_care['first_careunit'].map(mortality_rate)

# Cap age 
demo_care['age_capped'] = np.where(demo_care['anchor_age'] > 89, 90, demo_care['anchor_age'])

#aggregated age
bins = [21, 40, 65, 80, 90, np.inf]
labels = ['young_adult', 'adult', 'senior', 'elderly', '90_plus']

demo_care['age_group'] = pd.cut(
    demo_care['age_capped'],
    bins=bins,
    labels=labels,
    right=False,       
    include_lowest=True
)

#encoding age_group
demo_care['age_group']=le.fit_transform(demo_care['age_group'].astype(str))

# Reduces right skew in LOS
demo_care['log_los'] = np.log1p(demo_care['los'])

# %%
demo_care
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 126    10023239  33846653  medical/surgical intensive care unit (micu/sicu)
# 127    10023239  35024147  medical/surgical intensive care unit (micu/sicu)
# 128    10001725  31205490  medical/surgical intensive care unit (micu/sicu)
# 129    10035631  30932571  medical/surgical intensive care unit (micu/sicu)
# 130    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
#
#            los  gender  anchor_age  anchor_year_group  death_flag  insurance  \
# 0     7.702512       0          83                  1           0          4
# 1     5.452662       0          63                  1           0          4
# 2     0.872685       0          63                  1           0          4
# 3     3.766725       0          91                  1           0          1
# 4     1.037106       1          56                  1           0          4
# ..         ...     ...         ...                ...         ...        ...
# 126   2.825370       0          29                  1           0          4
# 127   2.432998       0          29                  1           0          4
# 128   1.338588       0          46                  0           0          4
# 129  10.494259       1          63                  0           1          4
# 130   3.349687       0          38                  0           1          4
#
#      language  ...  has_cardiac_issues  num_diagnoses num_procedures  \
# 0           1  ...                   1             25              2
# 1           0  ...                   1             12              1
# 2           0  ...                   1             12              1
# 3           1  ...                   1             66              1
# 4           1  ...                   1             44             13
# ..        ...  ...                 ...            ...            ...
# 126         1  ...                   0             29              3
# 127         1  ...                   0             29              3
# 128         1  ...                   0             18              3
# 129         1  ...                   1            101             21
# 130         1  ...                   0             31              7
#
#     num_drugs readmission_flag  icu_type_encoded  mortality_rate_by_unit  \
# 0          48                0                 5                0.000000
# 1          30                1                 6                0.333333
# 2          30                1                 4                0.000000
# 3          52                0                 8                0.312500
# 4          82                1                 8                0.312500
# ..        ...              ...               ...                     ...
# 126        50                1                 3                0.400000
# 127        50                1                 3                0.400000
# 128        35                0                 3                0.400000
# 129       176                0                 3                0.400000
# 130        74                0                 3                0.400000
#
#      age_capped  age_group   log_los
# 0            83          2  2.163612
# 1            63          1  1.864493
# 2            63          1  0.627373
# 3            90          0  1.561659
# 4            56          1  0.711530
# ..          ...        ...       ...
# 126          29          4  1.341655
# 127          29          4  1.233434
# 128          46          1  0.849547
# 129          63          1  2.441848
# 130          38          4  1.470104
#
# [131 rows x 30 columns]

# %%
demo_care.isna().sum()
# Out:
# subject_id                0
# stay_id                   0
# first_careunit            0
# los                       0
# gender                    0
# anchor_age                0
# anchor_year_group         0
# death_flag                0
# insurance                 0
# language                  0
# marital_status            0
# race                      0
# diagnoses_name            0
# procedure_name            0
# drug                      0
# is_elderly                0
# los_hours                 0
# long_stay_flag            0
# death_within_24h_flag     0
# has_diabetes              0
# has_cardiac_issues        0
# num_diagnoses             0
# num_procedures            0
# num_drugs                 0
# readmission_flag          0
# icu_type_encoded          0
# mortality_rate_by_unit    0
# age_capped                0
# age_group                 0
# log_los                   0
# dtype: int64

# %%
demo_care
# Out:
#      subject_id   stay_id                                    first_careunit  \
# 0      10018328  31269608                                    neuro stepdown
# 1      10020187  37509585   neuro surgical intensive care unit (neuro sicu)
# 2      10020187  32554129                                neuro intermediate
# 3      10012853  31338022                               trauma sicu (tsicu)
# 4      10020740  32145159                               trauma sicu (tsicu)
# ..          ...       ...                                               ...
# 126    10023239  33846653  medical/surgical intensive care unit (micu/sicu)
# 127    10023239  35024147  medical/surgical intensive care unit (micu/sicu)
# 128    10001725  31205490  medical/surgical intensive care unit (micu/sicu)
# 129    10035631  30932571  medical/surgical intensive care unit (micu/sicu)
# 130    10032725  30101877  medical/surgical intensive care unit (micu/sicu)
#
#            los  gender  anchor_age  anchor_year_group  death_flag  insurance  \
# 0     7.702512       0          83                  1           0          4
# 1     5.452662       0          63                  1           0          4
# 2     0.872685       0          63                  1           0          4
# 3     3.766725       0          91                  1           0          1
# 4     1.037106       1          56                  1           0          4
# ..         ...     ...         ...                ...         ...        ...
# 126   2.825370       0          29                  1           0          4
# 127   2.432998       0          29                  1           0          4
# 128   1.338588       0          46                  0           0          4
# 129  10.494259       1          63                  0           1          4
# 130   3.349687       0          38                  0           1          4
#
#      language  ...  has_cardiac_issues  num_diagnoses num_procedures  \
# 0           1  ...                   1             25              2
# 1           0  ...                   1             12              1
# 2           0  ...                   1             12              1
# 3           1  ...                   1             66              1
# 4           1  ...                   1             44             13
# ..        ...  ...                 ...            ...            ...
# 126         1  ...                   0             29              3
# 127         1  ...                   0             29              3
# 128         1  ...                   0             18              3
# 129         1  ...                   1            101             21
# 130         1  ...                   0             31              7
#
#     num_drugs readmission_flag  icu_type_encoded  mortality_rate_by_unit  \
# 0          48                0                 5                0.000000
# 1          30                1                 6                0.333333
# 2          30                1                 4                0.000000
# 3          52                0                 8                0.312500
# 4          82                1                 8                0.312500
# ..        ...              ...               ...                     ...
# 126        50                1                 3                0.400000
# 127        50                1                 3                0.400000
# 128        35                0                 3                0.400000
# 129       176                0                 3                0.400000
# 130        74                0                 3                0.400000
#
#      age_capped  age_group   log_los
# 0            83          2  2.163612
# 1            63          1  1.864493
# 2            63          1  0.627373
# 3            90          0  1.561659
# 4            56          1  0.711530
# ..          ...        ...       ...
# 126          29          4  1.341655
# 127          29          4  1.233434
# 128          46          1  0.849547
# 129          63          1  2.441848
# 130          38          4  1.470104
#
# [131 rows x 30 columns]

# %%
cols_to_drop=['subject_id','stay_id','first_careunit','anchor_age','diagnoses_name','procedure_name','drug']

demo_care_clean=demo_care.drop(columns=cols_to_drop,errors='ignore')

# %%
demo_care_clean
# Out:
#            los  gender  anchor_year_group  death_flag  insurance  language  \
# 0     7.702512       0                  1           0          4         1
# 1     5.452662       0                  1           0          4         0
# 2     0.872685       0                  1           0          4         0
# 3     3.766725       0                  1           0          1         1
# 4     1.037106       1                  1           0          4         1
# ..         ...     ...                ...         ...        ...       ...
# 126   2.825370       0                  1           0          4         1
# 127   2.432998       0                  1           0          4         1
# 128   1.338588       0                  0           0          4         1
# 129  10.494259       1                  0           1          4         1
# 130   3.349687       0                  0           1          4         1
#
#      marital_status  race  is_elderly   los_hours  ...  has_cardiac_issues  \
# 0                 0    15        True  184.860278  ...                   1
# 1                 4     5       False  130.863889  ...                   1
# 2                 4     5       False   20.944444  ...                   1
# 3                 8     0        True   90.401389  ...                   1
# 4                 6    15       False   24.890556  ...                   1
# ..              ...   ...         ...         ...  ...                 ...
# 126               2    15       False   67.808889  ...                   0
# 127               2    15       False   58.391944  ...                   0
# 128               4    15       False   32.126111  ...                   0
# 129               4    14       False  251.862222  ...                   1
# 130               6     0       False   80.392500  ...                   0
#
#      num_diagnoses  num_procedures  num_drugs  readmission_flag  \
# 0               25               2         48                 0
# 1               12               1         30                 1
# 2               12               1         30                 1
# 3               66               1         52                 0
# 4               44              13         82                 1
# ..             ...             ...        ...               ...
# 126             29               3         50                 1
# 127             29               3         50                 1
# 128             18               3         35                 0
# 129            101              21        176                 0
# 130             31               7         74                 0
#
#      icu_type_encoded  mortality_rate_by_unit  age_capped  age_group   log_los
# 0                   5                0.000000          83          2  2.163612
# 1                   6                0.333333          63          1  1.864493
# 2                   4                0.000000          63          1  0.627373
# 3                   8                0.312500          90          0  1.561659
# 4                   8                0.312500          56          1  0.711530
# ..                ...                     ...         ...        ...       ...
# 126                 3                0.400000          29          4  1.341655
# 127                 3                0.400000          29          4  1.233434
# 128                 3                0.400000          46          1  0.849547
# 129                 3                0.400000          63          1  2.441848
# 130                 3                0.400000          38          4  1.470104
#
# [131 rows x 23 columns]

# %%
train_df,temp_df=train_test_split(demo_care_clean,
                                 test_size=0.4,
                                 stratify=demo_care['death_flag'],
                                 random_state=42)

val_df, test_df=train_test_split(temp_df,
                                test_size=0.5,
                                stratify=temp_df['death_flag'],
                                random_state=42)

#check the shape
print(f"Train: {train_df.shape}")
print(f"Validation: {val_df.shape}")
print(f"Test: {test_df.shape}")

# Optional: confirm stratification
print(train_df['death_flag'].value_counts(normalize=True))
print(val_df['death_flag'].value_counts(normalize=True))
print(test_df['death_flag'].value_counts(normalize=True))
# Out:
# Train: (78, 23)
# Validation: (26, 23)
# Test: (27, 23)
# death_flag
# 0    0.653846
# 1    0.346154
# Name: proportion, dtype: float64
# death_flag
# 0    0.653846
# 1    0.346154
# Name: proportion, dtype: float64
# death_flag
# 0    0.666667
# 1    0.333333
# Name: proportion, dtype: float64

# %%
# creating folder for exported data
final_data_path = os.path.join("..", "Data", "Final Data")
os.makedirs(final_data_path, exist_ok=True)

# %%
# Export dataset
demo_care.to_csv(os.path.join(final_data_path, "demo_care.csv"), index=False)
demo_care_clean.to_csv(os.path.join(final_data_path, "demo_care_clean.csv"), index=False)
train_df.to_csv(os.path.join(final_data_path, "train_dataset.csv"), index=False)
val_df.to_csv(os.path.join(final_data_path, "validation_dataset.csv"), index=False)
test_df.to_csv(os.path.join(final_data_path, "test_dataset.csv"), index=False)
